# %% [markdown]
# ## Homework 3: Symbolic Music Generation Using Markov Chains

# %% [markdown]
# **Before starting the homework:**
#
# Please run `pip install miditok` to install the [MiDiTok](https://github.com/Natooz/MidiTok) package, which simplifies MIDI file processing by making note and beat extraction more straightforward.
#
# You’re also welcome to experiment with other MIDI processing libraries such as [mido](https://github.com/mido/mido), [pretty_midi](https://github.com/craffel/pretty-midi) and [miditoolkit](https://github.com/YatingMusic/miditoolkit). However, with these libraries, you’ll need to handle MIDI quantization yourself, for example, converting note-on/note-off events into beat positions and durations.

# %%
# run this command to install MiDiTok
! pip install miditok
# Out:
# Collecting miditok
#   Downloading miditok-3.0.5.post1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from miditok) (0.30.2)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.11/dist-packages (from miditok) (2.0.2)
# Collecting symusic>=0.5.0 (from miditok)
#   Downloading symusic-0.5.7-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: tokenizers>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from miditok) (0.21.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from miditok) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.16.4->miditok) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.16.4->miditok) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.16.4->miditok) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.16.4->miditok) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.16.4->miditok) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.16.4->miditok) (4.13.2)
# Collecting pySmartDL (from symusic>=0.5.0->miditok)
#   Downloading pySmartDL-1.3.4-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from symusic>=0.5.0->miditok) (4.3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.16.4->miditok) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.16.4->miditok) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.16.4->miditok) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.16.4->miditok) (2025.4.26)
# Downloading miditok-3.0.5.post1-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 5.5 MB/s eta 0:00:00
# Downloading symusic-0.5.7-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 53.8 MB/s eta 0:00:00
# Downloading pySmartDL-1.3.4-py3-none-any.whl (20 kB)
# Installing collected packages: pySmartDL, symusic, miditok
# Successfully installed miditok-3.0.5.post1 pySmartDL-1.3.4 symusic-0.5.7

# %%
# comment this out when submitting
# !pip install midiutil
# Out:
# Collecting midiutil
#   Downloading MIDIUtil-1.2.1.tar.gz (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: midiutil
#   Building wheel for midiutil (setup.py) ... done
#   Created wheel for midiutil: filename=MIDIUtil-1.2.1-py3-none-any.whl size=54569 sha256=a840d036aaa4a5e39e56ca6ed8acac381f004862d6961d2920b8629048252542
#   Stored in directory: /root/.cache/pip/wheels/6c/42/75/fce10c67f06fe627fad8acd1fd3a004a24e07b0f077761fbbd
# Successfully built midiutil
# Installing collected packages: midiutil
# Successfully installed midiutil-1.2.1

# %%
# import required packages
import random
from glob import glob
from collections import defaultdict

import numpy as np
from numpy.random import choice

from symusic import Score
from miditok import REMI, TokenizerConfig
from midiutil import MIDIFile

# %%
# You can change the random seed but try to keep your results deterministic!
# If I need to make changes to the autograder it'll require rerunning your code,
# so it should ideally generate the same results each time.
random.seed(42)

# %% [markdown]
# ### Load music dataset
# We will use a subset of the [PDMX dataset](https://zenodo.org/records/14984509).
#
# Please find the link in the homework spec.
#
# All pieces are monophonic music (i.e. one melody line) in 4/4 time signature.

# %%
# comment this out when submitting
# !unzip PDMX_subset.zip
# Out:
# Archive:  PDMX_subset.zip
#    creating: PDMX_subset/
#   inflating: PDMX_subset/QmWCdYmueNZMNSW4sK3Dd6ogXKjV1RkaUcrmm3nd7iKZAQ.mid
#   inflating: PDMX_subset/QmZZE6Xnfgiw9RgYiCL1h5x3j9jocazqWha5k9LETrGt9B.mid
#   inflating: PDMX_subset/QmYkLzny11AS5tr543YTcrNsLaLaHeQWWTUbHsLpR7nH2g.mid
#   inflating: PDMX_subset/QmWh8zMp4pi6aG4t9i5HgVrzYsJRLdQoZucCkaebfou5qK.mid
#   inflating: PDMX_subset/QmTkcC9pKEUNofoSW4Tuxb7vCeugW7kD3DBUEWkeUoKFPv.mid
#   inflating: PDMX_subset/QmWGxGFTUgaLjkRPVtvNwuELZyRD4TRmmVCfSkrmxiQkNi.mid
#   inflating: PDMX_subset/QmXk4uVrEnJkBZXBr7mQoBeXebmYPtxZGerp5MExpYS3NR.mid
#   inflating: PDMX_subset/QmQ5pMi7ieqoTHghLhjAqSLX5ptY3639ocwGdt7ew9MRhn_0.mid
#   inflating: PDMX_subset/QmNzmh6KezdyMBotBTbHkh1wakhurGb4bQnB7hWhuwRRJ4.mid
#   inflating: PDMX_subset/Qmdatn9HR89XLxeva56MsvMHZqPCZP5vqHiVTJW3i4VZSB_0.mid
#   inflating: PDMX_subset/QmXP8V39GGaXMSM5m19Zx7oEVN9mNpSB6fqVmQt3feetBr.mid
#   inflating: PDMX_subset/QmUsNp1UGDKxb5pHbeK5wxjwV4cakJyciW9nJ4gAoRSSk7.mid
#   inflating: PDMX_subset/QmXWXffj94mT1Eg2mAfUpnvLT69RTJmPQUMPYcuMSJMzL3_1.mid
#   inflating: PDMX_subset/QmYVGqm556wX9mYzZRhngTPVtFmNdUzocM5ZQV93weM9Ca.mid
#   inflating: PDMX_subset/Qma4s7tjTQkw4LV9d38XsmgrW4AERHY3m7TzLUvbv5MXXo.mid
#   inflating: PDMX_subset/QmQUgXFsYCeKfDVUb2kgVVKdmR75LVEAhSsgYyiEhvV8Rp.mid
#   inflating: PDMX_subset/QmQ9hhPiqYMsc1FJXVpLjTzjDY7uEqUGBKVvtk4B8KCzy9.mid
#   inflating: PDMX_subset/QmbJ5QZrca3BPva326D27MUbK1WTQYzNKTUVWBn2FqmKgw_0.mid
#   inflating: PDMX_subset/QmV7hVCkYoY3uXDMgQxwurZost2tRB1fb34zdZNYKAujUx.mid
#   inflating: PDMX_subset/QmTfiL61v31FURkfjdiJZKrUbNfJH8sSrFyyNyAa8zcQ5V.mid
#   inflating: PDMX_subset/Qmep49KRfNGYraBVmuV8FRuoGbmP9KHG35M2FgowAgAd3s_0.mid
#   inflating: PDMX_subset/QmSZLvy1WxxkwrpanyzepRSMZMLGVWfanqYzz5ViWoSRpC.mid
#   inflating: PDMX_subset/QmSHQ7W3xDVH8pcPiDmd2pK2qeM8btivW6x51KCbWaGnuj.mid
#   inflating: PDMX_subset/QmPXfjzN3Yx4vnPkmv8BND9L7hGxy6cNazTWyc737uPA62.mid
#   inflating: PDMX_subset/QmbtUVGW3PaXg4eabAB7FZ6zCE25yg8JhWdfHKfYX54Gc2.mid
#   inflating: PDMX_subset/QmYPdTjDj3oZJWqaJnWWPjrXmguNUgkB3GnphfUAYVUwQo.mid
#   inflating: PDMX_subset/QmTE6EPCM4hx6KrP1EC4f6xv2frcQ9fzYBwqNMnqQZksWM.mid
#   inflating: PDMX_subset/QmTTUodgtifuUgVxb7kSbT4DoaqwdxkESEpuFAaoCEdkdy.mid
#   inflating: PDMX_subset/QmNVT2m1CgRjpx47EY76HYynVAktE45qvgUAkm7YKeRNnP.mid
#   inflating: PDMX_subset/QmZQyn8TbfQMbErvN7TEqKeRNKvYjyACopN2smk35vQ4at_0.mid
#   inflating: PDMX_subset/QmahQ9s1nspk9c4HKsMUGuDHfaTYRZUZa3icn7Y4mJwb5h_0.mid
#   inflating: PDMX_subset/QmZPxydDCCp39hPoXAn9FQC9ZdLXfmno9PvHKCWcgmsx6c.mid
#   inflating: PDMX_subset/QmcxzQPf6LMWLx6Kj6z7bH7BmsrGhusMX8as9GEsyF8yAA.mid
#   inflating: PDMX_subset/QmQe8yKPo8Shg8Y5cz5vNFLUdxVrji2E2cgfzMyzjpeZXZ.mid
#   inflating: PDMX_subset/QmaRNUfa4p2Wf5uifWF5HcW9oKF34q1Yswhy98tZPeQQZY.mid
#   inflating: PDMX_subset/QmPHCW3auCEm5i33ccYvjk8Jt897EKkgbn9v3oPQG4A13C.mid
#   inflating: PDMX_subset/QmYWcqDmya7a289fdbipTHNzZfoxgHt8NaiApvTuqvR5GM.mid
#   inflating: PDMX_subset/QmZyM9NeKgRj8woVQAd8jZQN569bwG8xM95qpykCGhaJqq.mid
#   inflating: PDMX_subset/QmfSjax1RtumTjqsQhmgUcbTAyawfY5hjf4u9QUhsg5kAp.mid
#   inflating: PDMX_subset/QmTKQddBqKFLf133ojHncftWzhe4ypomFYWrjHmmjpSqsE.mid
#   inflating: PDMX_subset/QmTvyeY52jXLhyvAnDXCUTFjvSN9rpgRYvx7uUUSrCgJSr_0.mid
#   inflating: PDMX_subset/QmUBAwf8DcQ4s4pWtXbCYrVrkJVRrsdWTUn7nh3FLen72d_0.mid
#   inflating: PDMX_subset/QmQhPoVDBo5Famgj7YU8BrrQ2wxi7DxbuUVsYYRo3zP1mX.mid
#   inflating: PDMX_subset/QmTDzJ4riZ7mRZXgAPR3YfaQiW8D8vhTA8NszSLYc7j93U.mid
#   inflating: PDMX_subset/QmWWacGAPNkQhPo1Tr1ZLvx3whDA7ANVoJMUzJAVn5x9Xi.mid
#   inflating: PDMX_subset/QmeQdgjQTGv9u9xdR9r5LrwUpLoyEdZk1CWUdufbnq2Q4n_0.mid
#   inflating: PDMX_subset/QmfTD1yvvD9C9ya4rRpx4BGpMz1AgaXuYmbCNSm3roW3Vj_1.mid
#   inflating: PDMX_subset/QmRC1rthpQR4T8BwMpABk7UWjYwdA3yvWQ1qUFCJT6vZ8h_1.mid
#   inflating: PDMX_subset/QmS3aCn6yKu5bo4actMiMqesxiFTLPpbn4RRwavK6kfzAh.mid
#   inflating: PDMX_subset/QmUv1uMUu3ZdK8RZFGcbvGANSDQ1Q5AfWu81SYQssW4Yxk_0.mid
#   inflating: PDMX_subset/QmP27uo5UpQCxh4gpJYW1LcnpeZamagmdmvBRBydpxbdNW_2.mid
#   inflating: PDMX_subset/QmTo6LdqxHtHtNERV2D4ikNwdTVwh87zUim5dGwBKdAqm5.mid
#   inflating: PDMX_subset/QmPCnqrvvL6hNvQ3XjCmrzrTSMFg6TeD2fSm3fGwgij43c.mid
#   inflating: PDMX_subset/QmW9wnWgTonFzFuNpBLyf3dLV2Qgtidjsa8B1wkFY1AcL3.mid
#   inflating: PDMX_subset/Qmc5dCNpgFARtLKowTFmkasf7xya1o6qMeGPVs6GpYXo9N.mid
#   inflating: PDMX_subset/QmbG5UG4oKHhdhY1nYpJx52otZLQtMueqocX6DHLxADaoW.mid
#   inflating: PDMX_subset/QmVsTnKB2VvuoMmtCEKt7FgjnENWahXDyRW8bxhPNAx7Tn.mid
#   inflating: PDMX_subset/QmV5WPF8qT3jjdx9NGrStRmuRkBDL1Kp2CCBCPuAbzVrx3.mid
#   inflating: PDMX_subset/QmVmvKBVAijymuKkgQxRRidz2UhpptwdqCYjEgJ7YuJBu6.mid
#   inflating: PDMX_subset/QmSKaWSHvSB7yeXHTcEan7yDKPyFjAobEhRVvEtLF8WsSV.mid
#   inflating: PDMX_subset/Qmdmkwp6xmebyCzULE4KP9VZAXyUbTmD1gXh4JMWcYEQDH.mid
#   inflating: PDMX_subset/QmWfUXSCkiFqVMuUSjvwNSnvXMqd4A9aRLN3VxdMErCVpQ.mid
#   inflating: PDMX_subset/QmXCeNnEQf48bvWABvcfSRzSqputSmg7x7ha3aM4CXQaH8_3.mid
#   inflating: PDMX_subset/QmScRWMtV2YUih2LAGFEdGTaYGcFAig3d1bJtasDvfZxzg.mid
#   inflating: PDMX_subset/QmdzuuqaqYGdtpwGGysQPmtC8oTwy39UtyiMCsLqxcQBTa.mid
#   inflating: PDMX_subset/QmP5ffC8jwcoLUDwb9soMQXMRG6RVJXuEGhvmrHaKcrLcS_0.mid
#   inflating: PDMX_subset/QmXRmobnGGq3QURUnXxCWYRMJZUnNMsXhkiuTbk4CcQ9N5.mid
#   inflating: PDMX_subset/QmeMriFaG6bLpHgWtt2h8rtATFNtX14ooosPa33GWJTUcy_0.mid
#   inflating: PDMX_subset/QmeyPtR3gcmRS5BhX3Egdg4fcFBQNm15LX9MGYNTjMny3y.mid
#   inflating: PDMX_subset/QmVsp9UASd5SgDfW1m1XmY3G7Un2rq22ax1yjc1kKar2fr_1.mid
#   inflating: PDMX_subset/QmSELRHJbT4vBLNPE8FzhzZ6w5RqNwgP36a142c5qRewd3_1.mid
#   inflating: PDMX_subset/QmYEb7xisZiNz5ftGTDCYGpPgxVGqtWDP6i5Y1J2qW2EnZ.mid
#   inflating: PDMX_subset/QmU2j8hCMGSYUZumPxYPVC4iJzm7U8zQGm6cVvkyL9ngsR.mid
#   inflating: PDMX_subset/QmRnTy5fLyE48sDqFdP9GAQydzczh2gdVRFzuEvAdVZJmG.mid
#   inflating: PDMX_subset/QmPZ3ae38oF45gzAXUrEiVXLBG2HXXeUwXcdyHzRQHNrpo_2.mid
#   inflating: PDMX_subset/QmYciXvCvnUWo7NEfMMdsM6sMiiQc1cxJ2WLxKn54bBicF.mid
#   inflating: PDMX_subset/QmXttGhRwyi8EXByW7X1atmQGbVUjnQjVmpEg8hwVAocKP.mid
#   inflating: PDMX_subset/QmVN69Z3zrRzMt1npEF5W9citHhHehFXWmsuiEYe3H79KL.mid
#   inflating: PDMX_subset/QmZ3a2sXFc2wvDDnsyh1bA6DEpasN55MHb1FTAfsJgv1tq.mid
#   inflating: PDMX_subset/QmT5yFj1bbBCe7V4K7GeBMX9x9rSqUpchivDRnS2GP3A6Y.mid
#   inflating: PDMX_subset/QmXEgmiWbAwoCT836PTeJ97znZkuGuMF9BRPvA8Xq5Nwvy.mid
#   inflating: PDMX_subset/QmdW5fuqaXkr4keC4sDteNzVuv4VW1ZfsEa7aR4fPYAEAP.mid
#   inflating: PDMX_subset/QmVvvhsveWhDEUDD2bv2YNF4XPTM4M1ViodfS5ctiNbfz6.mid
#   inflating: PDMX_subset/Qmb1YFoQuDHbwhD1wUdymWXXf3Bn8C4vdJj7a8Y4EDCVDc.mid
#   inflating: PDMX_subset/QmXYk8axNnfY5wLurfVormHgdfgSenbyY8XhoHUdNfnfaU.mid
#   inflating: PDMX_subset/QmQXJitfPLLFzEonJgh5dZvHsiRXdyA6hkCmK7J9BAr1wo.mid
#   inflating: PDMX_subset/QmduFx5KLkAjuxs7uugMB8Zymt4mzVrTmUT4FDT3Fq4Hfg_0.mid
#   inflating: PDMX_subset/QmX3F8ZfmjLzpietns8XhUr1Wqm55rJ66oubzUFLqfzfev.mid
#   inflating: PDMX_subset/QmZNXQTLW47bhtoerHmnwAmEqjQWqafheWzUtEekgJ78XQ.mid
#   inflating: PDMX_subset/QmY9wDv83oYtc39XVGi7ohikFcHk9BjZmeFURmD8ZB82hN.mid
#   inflating: PDMX_subset/QmWnUdTeStcFndtMNMD44n3b2g1V1ZXhyjUg1yGAyZv1Xa.mid
#   inflating: PDMX_subset/QmTPSnNVB2oaSaFLP5JTB1yhhd5CxGTYRERUx9q8f9oK6A.mid
#   inflating: PDMX_subset/QmZBSZcU5vQd5b3RQ6Lb3wwm31iNnznvJPVWtjPsEPmYqs.mid
#   inflating: PDMX_subset/QmV5RjJ6AWjfoUDBJeWTqaArUWbD3noANcThrPYKPDq7mT_0.mid
#   inflating: PDMX_subset/QmShKhVeKqbY4mRvdq3tvwR9Qnbf2wAQsM8g4YbnCUUeBh.mid
#   inflating: PDMX_subset/Qmcjh1FJ7KcQjoTfCfqCPSXTEA8jQ5xWBctMSB5sVyhB8h.mid
#   inflating: PDMX_subset/QmcyixmHgDkAZMCipqFj4kEFdHednvuMaGkzX4PvGsqfPe.mid
#   inflating: PDMX_subset/QmbcA77FYU3RJrwwj4rADopg6MJEy4Tn67YM3dPPWWKtDM.mid
#   inflating: PDMX_subset/QmPPwSTKstkx2SYaQL9hYG5Cxt1hSsbKQxp2tFxd6d5Fya.mid
#   inflating: PDMX_subset/QmVaaB165yMRjYShYr2s54ZC297wLokdRPsxGgXdkdFKfH.mid
#   inflating: PDMX_subset/QmUZsoTjgP6caaBjBVAAXvs4VxjRjhE9svPgdFtA9ScDrc_0.mid
#   inflating: PDMX_subset/QmXuR4rgaWf9K4nX3u4uvAMuY7KP6arj1yeJFZTvMmZFXe.mid
#   inflating: PDMX_subset/QmNaef4gViEuaCJ7r7RyEzqmtcdRp7eQvXtDaoPa33zwXT_0.mid
#   inflating: PDMX_subset/Qmaa14YaWBde5JxMLcyLDfbvmagtfKqMyt22uCe8EKYoD1.mid
#   inflating: PDMX_subset/QmXTqmw2KtRy3XhYkVhMiXv2RzgbtKL7C3WYXDFNaRyA3g.mid
#   inflating: PDMX_subset/QmdgxrohkhwCcfKpgKx2WQUdKNru9j7yXoEq6ocBrgvPxm.mid
#   inflating: PDMX_subset/QmdFgUz9ydduAVaWzoqqwGrLZXwin4amqSaG8UGssGyDrQ.mid
#   inflating: PDMX_subset/QmTmcP6NQBm1S38WNCUcoasQRyoHvHV3cGQtpVLK8SqnsM.mid
#   inflating: PDMX_subset/Qmc47QHbUxQTjwtM8YERE1NcRNfuRd961evVD3CneFLMCh_0.mid
#   inflating: PDMX_subset/QmUhmkpVZv9jV6fxtdk9MXXVzts6y7cCvvDXnz5wYfYRuU_0.mid
#   inflating: PDMX_subset/Qmb3q7zcNK9Kw8EPcojdK3FHsLnBGuEzegr5TtDTLB5Y4q.mid
#   inflating: PDMX_subset/QmdswBapVMeFmvipHsafxUsHVqQv8wb7pFbkffT7kKoHTV.mid
#   inflating: PDMX_subset/QmY2pcJmeSo9ori9cAi7XWuspSdQhtGaqpdZu5X7VTSujs.mid
#   inflating: PDMX_subset/QmWRT9UuVZ55qZm9Y2B6qGdCtpdeMh6dve6fiTTrE9hb8b.mid
#   inflating: PDMX_subset/QmVbA2fhsNF9aPfs2sJD5peApK4tqUkDiPh6Gig9m4EYcy.mid
#   inflating: PDMX_subset/QmNX98vFa1mmuBvyLzcfnysG4zQBS3rvFFezT3qL26n1qj.mid
#   inflating: PDMX_subset/QmdPU3bc9sR6eaZU1aMivWkexNzWm4MxnAJkQwe9tEkYUP_0.mid
#   inflating: PDMX_subset/QmRau8mpL5fmHNwXKv62oKw7k8V7C6WAQBv44a5Cc275Dt.mid
#   inflating: PDMX_subset/QmZGzHPz2YwEYMgGaJuj3x4Zg42wLhWLYrPA1VZuy7JPKc.mid
#   inflating: PDMX_subset/Qmc7bYDCojxWCv6KQS9EFFLTAB7LtWkw2Cw4poRhngg4ty.mid
#   inflating: PDMX_subset/Qmcwm4B44PNJmPyqJMvWo1cKBJyJgPECS2dbgiSphPeD6g.mid
#   inflating: PDMX_subset/QmfJJM7UybkPSuo6KC1fu4Zvh1RzNDQMhL1hMfwXyXEwrT.mid
#   inflating: PDMX_subset/QmY3eePZQs27HAyTBD5L5qgoj86oJ6adnVDFwUEnpSnDR5.mid
#   inflating: PDMX_subset/Qmd4NBeXSrFyX3tbPB2NdviGY4Gn91waWbyviMcusBGHZ4.mid
#   inflating: PDMX_subset/QmZHUDYXyJBuymbLy4y3uviAktCTMn8KU2WVPmY1kCjvGw_1.mid
#   inflating: PDMX_subset/QmdRTG73TjQH3mGiwicXxjLy4Nk2is62o38p7YsBKFXSrL_0.mid
#   inflating: PDMX_subset/QmNhJKpwozdYG199KWowvj2XokM2JGMBEfWfdCaokhsqEv_3.mid
#   inflating: PDMX_subset/QmPyV6xgFPHTyVdWHn82MsNtx5X9htnKZFCuwP4Ziakwoh.mid
#   inflating: PDMX_subset/QmRmPnFuBUkZ8nvb4Y17edGqmSP1JTLrn59cXBEVdCeH8V_0.mid
#   inflating: PDMX_subset/QmZGxVdGKedC693HB5D6j9enqJWV8BA3t1SCdMYcnmmykA_1.mid
#   inflating: PDMX_subset/QmPM8G7qCx5mm5EVJcnZaJEDkTvYZJ62xrhQjVd59ncZ7P.mid
#   inflating: PDMX_subset/Qmf53gviXfbMApVJPLafpj1EWuCKtvm7F1gTLRft71TEJL_0.mid
#   inflating: PDMX_subset/QmdrmxYur9JxKoaCEjjrhBgN1PBjYEwVJKcnTbghooNr2f.mid
#   inflating: PDMX_subset/QmdTyqpB3HiU2i3nyBDi8qFBTTDR2gdQB8cwp1vbZhSEZU.mid
#   inflating: PDMX_subset/QmcTKyaRYrma9eqrrSxHHkANwHfn8hR5ZU6XkC2x16gYQe.mid
#   inflating: PDMX_subset/QmURsjiTZxwQnL2VMtS9jUutXVmSnRGKAQAJCG2ssbBFNz.mid
#   inflating: PDMX_subset/Qmf1oDoTFBppjkNxCHjjV2Us1XNZzNFW8toaZZocj384Va.mid
#   inflating: PDMX_subset/QmQs1qWhLNSYhmC8wckF59e7TTq4SoFWvyWDKKd8rGgU7m.mid
#   inflating: PDMX_subset/QmdEaMGx3955Nv4xNnEGjwBB1e4csQaK6zPP62Aa7MVRQv_1.mid
#   inflating: PDMX_subset/QmPLiwQTJ13yvbWJK8JBSQRD13JWjp92E52Rcej7z5zyFh.mid
#   inflating: PDMX_subset/QmZwsUZ4cza6nKKLcMbNQLNJ5SM2xmTBFKbYRXvcVmAWEY.mid
#   inflating: PDMX_subset/QmfYsAUdyHT6FKjz3LZ4se8DT2s31Hp8bZGH1Jwb9z2Gc7_1.mid
#   inflating: PDMX_subset/QmaGF7fFEFRKVCVoRQpWKWZhdLMRP8a3G3MyTfSw67ugZm_0.mid
#   inflating: PDMX_subset/QmP5X5rtRWVTfGchqPpx5XskiaZabPQUNZkug2eHE5ScMH.mid
#   inflating: PDMX_subset/QmTAx6rEGFEGeq6zJpohELh24Fytch1H9o5wstV1EaUcJX.mid
#   inflating: PDMX_subset/QmUAjpxLjg7eJpKBUTKXtJW7qH7acfJReLuFWBm7CBtUe7.mid
#   inflating: PDMX_subset/QmVfJwPMjCGvcPVFrWCLfxyAHqb5iNHFoq2adVCtSojsBT.mid
#   inflating: PDMX_subset/QmdqxpvKAKj6cgJ2Y4H28hKWgE1uheLcYnsRr6N4cK5A9t.mid
#   inflating: PDMX_subset/QmQCqqLZNiKnDDEzykGjAqLc7tW7kdUBN98TPL23M7ijxi.mid
#   inflating: PDMX_subset/QmQj2sQp4djidL5sVAtZzxSGQdxsQeSJ5mAFZtZpYumNes_0.mid
#   inflating: PDMX_subset/QmXzaTCxBeXwsdZBetUcYR7btziquLKjfGoyjnMQyB3Xti.mid
#   inflating: PDMX_subset/QmNXyNXedUC5MwaL1XSYsiUs9WeeRTnStVE9rz5YjuRgKM.mid
#   inflating: PDMX_subset/QmcqFP1c8JYgzRMyDovpi33LWCsfhjdr9DTDnRXvhYhh7g_1.mid
#   inflating: PDMX_subset/QmfXLr86Agk32QxyREyaNRi4Rfsa6mecPmh9opseQWmJbK_0.mid
#   inflating: PDMX_subset/QmSvVDKJ64KqxkVhwHcNXtKKjYFn8q4zGnRBSJ8uePFHKz.mid
#   inflating: PDMX_subset/QmcEf4TeGKwEpgiUzrG51YSL8VNV7j1D2G9MzqXHMLqYtq_2.mid
#   inflating: PDMX_subset/QmNsJ9VpMJ3vgQer3LNtZNF9TVMGAKuSDtw8yPSUvdQMpQ.mid
#   inflating: PDMX_subset/QmQma7pPNhD6wnUEBrTaa7XdySsvKZr4nVjwCd6h6rUwvS.mid
#   inflating: PDMX_subset/QmfDkn7Mf4bMnFD7wYRAjbjdCxUCdn5HKEw7pgoAuijPJz.mid
#   inflating: PDMX_subset/QmbGUxZnUQiyTCCrJTaReecCsgpivy3zX4oR7TdXjiccaR.mid
#   inflating: PDMX_subset/QmegiS3NGpGyengzE15SDB8fyMFm8eEj95seTwVpF8ZhUy.mid
#   inflating: PDMX_subset/QmTpf5jAMFmMbEoDAbWgHwn3Rhk8mBk7rfDWcGmQsURZeZ.mid
#   inflating: PDMX_subset/QmUAUgNPD7VYiT2FayxzSMsG5nYvfdbvTj4dDvWW4oBokH.mid
#   inflating: PDMX_subset/QmSvjxQwq6N68qa95fcGQQedAafi2Hjga7BYuZHD4YD6wi.mid
#   inflating: PDMX_subset/QmZdxGiDSiRThBMDzm2usXoXAZfFRWG6HPFysk9ETSudG9_0.mid
#   inflating: PDMX_subset/Qme439pVu327qg7Jy1s3zc1vCwnifZHk4No6WMyGxeSmFw_0.mid
#   inflating: PDMX_subset/QmVLEx9pACUQnh1RdAtiKXUqhL4VvbNZmCm9kckWNMLW6F.mid
#   inflating: PDMX_subset/Qmda5c3nJD3cxwnEA4uC9upTJ7R2jkaJT4es3UYDrnh3PW.mid
#   inflating: PDMX_subset/QmeGK9Kc88uYuge7U6JSqvfGTLH3DJKneSRQftqjcsVL3n.mid
#   inflating: PDMX_subset/QmQYfBXzvH6sVCrXaHWxtb6FcCTqERL1gkWYELgTS3ufca.mid
#   inflating: PDMX_subset/QmWmVM8ZfUSnPusaK2TthjccP7pfU41WXAwgcN2sdd99xT_2.mid
#   inflating: PDMX_subset/QmY7m5k2Uw5TSUYrEGWEZpsetEACzMHiqFQrh5wemhfVGo.mid
#   inflating: PDMX_subset/QmPLuxVR6NVwF6DBCaoRiQZbdTwwobLu18R1NJVX9wAEeG.mid
#   inflating: PDMX_subset/QmR4TRhgatZ8rW8jbNxpyRoNNuyhFsyjELwXzE8NMg2aku.mid
#   inflating: PDMX_subset/QmSjzQTug7hXvgbfmoERFdrDnGwVZ6V8ZBUfn7Px3sEFXV.mid
#   inflating: PDMX_subset/QmRGWVL64MhXf2LBLN6uLeC8F4hFTbbZL2FAKS2sfzPHkp.mid
#   inflating: PDMX_subset/QmdUMjgo71ctSfrD425wMqupXwMpfmKzsUX2axLvJRsFi5.mid
#   inflating: PDMX_subset/QmcRwK8NWkJgiGNX4Jn54R8BAGBqZ9DdreQ3cZqyQ2pESN.mid
#   inflating: PDMX_subset/QmQ8DRB5a5Ys1n9SGhPiojwW5SRcsMzi3WzVwHc1b6aLqJ.mid
#   inflating: PDMX_subset/QmRCfkX2uzetW41DU2bEzwF3teqGu6ygdVmrW1jDFS2BUk.mid
#   inflating: PDMX_subset/QmaDXQxfLYWAhZ3Rkc42MVXiujTp4tmXpCZ1FgJ8o5ZcXk_0.mid
#   inflating: PDMX_subset/QmPfkXy2fz7fHrdysh5PWmHTyn33dFHPZDN7B8ooQbE6uM.mid
#   inflating: PDMX_subset/QmRCRuSUjWJuCNHJTN85W2jq5Fkn36t5TxFUXib3E5CFPY_1.mid
#   inflating: PDMX_subset/QmQ61K7pvZSccSkQGh9WU83KSg5o7e9B52jPSeXgVLhjzt.mid
#   inflating: PDMX_subset/QmbvC1EAEgPHJ1EQd2DoUX5epp3Sh8nqgHuhowCNFnTf8f_0.mid
#   inflating: PDMX_subset/QmdW85paTJr15EgphaPwfPtdKrCAsE5Zjh4XtKRGLP9XE2.mid
#   inflating: PDMX_subset/QmdBc2EXq1ENhffSqMvBP47UkqkwfvVSucDNrnxyV67Q44_0.mid
#   inflating: PDMX_subset/QmbWprzVCYFfikgVMViskLUt32LfddhKbq3E1UmUHGvj7p.mid
#   inflating: PDMX_subset/QmW3x7Vs4yT9DDdcpqRyGqQzQbqnNddMwFHw9PtiQd2bA6.mid
#   inflating: PDMX_subset/QmSQip4wMwtPpNHo3DM1tZua8k2xAsmZ3YsHPLREoXe1Vt.mid
#   inflating: PDMX_subset/QmWM8UgPXdi87VmWBm1p97Rnn7izw8R2ZvxLf32G3GBXGp.mid
#   inflating: PDMX_subset/QmUB33XnZrbLgbtoDWQK5kDh6zpUqkwLbj8B4R3CBMfScE_0.mid
#   inflating: PDMX_subset/QmfCpzthVjndtcJn2Vk6d28vFTeqJk6XqbZdHNs3QSF3j7_0.mid
#   inflating: PDMX_subset/QmRbMjQRiYzqcWu7eAWsJN6t2KzJbT7suQy1ZHGZH5KnpA.mid
#   inflating: PDMX_subset/QmRTYgczSf3R1muefgK1FwciYJqPS6VnWwUTFJPZnj1KPX.mid
#   inflating: PDMX_subset/QmWfZm4hJuyeJ4FfvJDAiFsTJ6obEkbH58s4HVDSFK9Y3Q_0.mid
#   inflating: PDMX_subset/Qmdyw6ncjnX2N3iB5qXPgZ8yqP6GeWMJvrto4YxJiLnB4F.mid
#   inflating: PDMX_subset/QmZ4rnHDVB9qb5HYsQ1uCpmHrYbxUNb2LMKpWez8o1pLTr.mid
#   inflating: PDMX_subset/QmZZihF7cHQY8t4rTK1Gyz4bjNTzVY2gSmzcgJpRGETfer.mid
#   inflating: PDMX_subset/QmeavwgbtChPpQJANV7v4nuUdgUVHxt87M93S1GrQguTsP_2.mid
#   inflating: PDMX_subset/QmQiA4YdEzt2DFnf57gV3G3MbwtWnY8Ajdh4tdSXStJpzn.mid
#   inflating: PDMX_subset/QmcUmRqYKdkWJ7RbUXSumnhNYTpJf9kk742LGNXa3gQHhV.mid
#   inflating: PDMX_subset/QmaXP25x2K4aLUsTxFtrpCVQme5Z66oX9jHVoZMyQj39Dw.mid
#   inflating: PDMX_subset/QmceXyQscmX7kWGdXAaBzwid3iPsgercnRLcmECLrtA8Ht.mid
#   inflating: PDMX_subset/QmTohVpum9DawqcYBgKG5hgzEbvRp4pY5NqKYx8wNxQmFg.mid
#   inflating: PDMX_subset/QmcB5tvtLqnoHjK3tB3ppVx2ke52qEHrfFk8SZjZYoF3wn.mid
#   inflating: PDMX_subset/QmdMKUxAGqKR1zHS7x1fkLE9q2avbsWnXE8ymitHXLgxsk.mid
#   inflating: PDMX_subset/Qmc8W99BE6AYi8ekLDPE6Q4pfPf9aBPA2QYM1fKitTPVqC.mid
#   inflating: PDMX_subset/QmcXm7X3gmNrmRgBEmu1QCu7Um1zCNcvcg8aVXtLFVatBG.mid
#   inflating: PDMX_subset/QmcWYnZ4XWTuW11tWSYgA5aAisqfPiS5QR3NpZWZtBsyog_0.mid
#   inflating: PDMX_subset/QmcFfJgw8AWAHzi2FCEJ4ApXqak39n2wmrYcfgYKgAXfFt.mid
#   inflating: PDMX_subset/QmRo1iRcNuSfm4YP3bEg5nWjtq5fpUXyXQwxtF2eF429vr.mid
#   inflating: PDMX_subset/QmZ2A8HJ28ak9gTMpTKyeLzVjBEtusCBRQ4eGJzKi7tEqF.mid
#   inflating: PDMX_subset/QmWChgCfkwcHYHQFb7Y4cTvDsGAH5qWaL1iE6ghzSQUqnR.mid
#   inflating: PDMX_subset/QmWpBeLRqhppLe8U82hxxGoqrnFhmw1N2fpC6ymsuWy2xh.mid
#   inflating: PDMX_subset/QmQJYwRBX7dwUxUdsjwveYpk4qbXSDqZCyYL3ySuLm6Pr9_0.mid
#   inflating: PDMX_subset/QmTAWkPfd2hASbGox9qro6ofbdLubrBoMRt4s1CCyfpHTo.mid
#   inflating: PDMX_subset/QmeT7N3NAkuqDn1yEM2Kb4ctyZL1YpxRgjcC387RGbPQu3.mid
#   inflating: PDMX_subset/QmQarYuaiiCMf9Qv5vxTLRJPDNDCXY53xBGNX5CJZGXu74.mid
#   inflating: PDMX_subset/QmXMVjatnEbKnPa5XnVpFRxiQGLaX9huejyj9XYRLhj6Zh_0.mid
#   inflating: PDMX_subset/QmYMyyQNjY3rHeTc4fCjJB6Mis8bdkwanQzTKbgXKxsJyf.mid
#   inflating: PDMX_subset/QmZRqssbmgesJLukqLFhcFyJX7Jr2cfGMPxNQKRS4ZD5Zo.mid
#   inflating: PDMX_subset/QmU5ev4GbjiGmZB8ZWDRHzsJCJJBDuLJotrwJMoVHVkg36_0.mid
#   inflating: PDMX_subset/QmdcP5FnveHntf2eM7eZW9vMuTn7LHwCGV4MW2VBZ2kKiN.mid
#   inflating: PDMX_subset/QmXipp6jq7PTwqyEAAMDj3LaoBRHiJA1tkCBUYEZ1qn95s_1.mid
#   inflating: PDMX_subset/QmZ78DkcAz6v8QUHU9VmXsQmTjz9pcDDV2qEES9HcUAQJw_1.mid
#   inflating: PDMX_subset/QmRCud34D7RH8odvXnZ9TWQaJWAYvPHAFGQ2ZcMkV49oxk_0.mid
#   inflating: PDMX_subset/QmQTP3MPT351qY5JBtMkXZyJakPwvtmV6XXV12z9pJYNcY_0.mid
#   inflating: PDMX_subset/QmdqJJsNWMWaHb6YJNwDVs8Crn9QtNXJUQmMwQvDpjBRFb.mid
#   inflating: PDMX_subset/QmbvCwTVkzLNTMX6bUxKCxip3Gd3jdvR8a9JioYLEVX6XV.mid
#   inflating: PDMX_subset/QmT9qHtBBvkZS8AARdRUT5pS5Vs3B2Bm78N7LXz6Keg4qa.mid
#   inflating: PDMX_subset/QmaGoJDbJEYL6m2PmFJ2Py6oahNXa1fdAhpLW98sG2Engy_1.mid
#   inflating: PDMX_subset/QmZ2sJg9i2VX4Jj92JTkeurrnJveJfuYgdzgaPLCZ1R6SE.mid
#   inflating: PDMX_subset/QmYXTAUjYqQ2PCxMWVyYJyrwLdCupJK7C4Te1qT6dyMA4R_0.mid
#   inflating: PDMX_subset/QmQDsyVe8t4XeFUUPxKBtCaDiD5MjrnE924tQbc3RAhKis.mid
#   inflating: PDMX_subset/QmQ1dQNCR6CKA4mPwaAS5WffTnfmRVkMd7ogxNsQf3uWWi_2.mid
#   inflating: PDMX_subset/QmQ6BJWaJMD1iSPckQts2eQ5itCwKSCGzD5JFRR4ctRdo3.mid
#   inflating: PDMX_subset/QmWuWuj7fT56hxUbSpgztxGXZoK3eRF9Z1vNtpkgnbSo3J_0.mid
#   inflating: PDMX_subset/QmThKfgJSaWaVhmdACJoihRM5hu9Kt8GdKtPAgTeiYUw3V_1.mid
#   inflating: PDMX_subset/QmVpgbdsZgWdciTKSCGoK5p7qiddKzxk75Mv2cig6bYM2n.mid
#   inflating: PDMX_subset/QmXDMaTq5f7kWhnKtW6SiE648aNSSV2LAUcobdc9ffWpeF.mid
#   inflating: PDMX_subset/QmQgMFcfSdpDQc4dKqEtV83V6GRf8TXkyGza6ojSGUwcSs.mid
#   inflating: PDMX_subset/Qmd8ZYDhGz6rXvmB1bdwHRB2yXYM4RXUFms1M9nVhvWF6g_1.mid
#   inflating: PDMX_subset/QmchfFYTJgRMXGsEH2gz4yQ2sAS3XYEyT3NyhY55Anjf9J.mid
#   inflating: PDMX_subset/QmVRJWfMR4sTJyUNYybW1BLPnKpf4LF5DrfSuh7X3GvQQ4.mid
#   inflating: PDMX_subset/QmQeRWqaFZaA4SphJzjDjFm23WJDxdKRySm8mdCMBE7VBk.mid
#   inflating: PDMX_subset/QmSK6JzwW8A9vHbTvmyhbmJk93RiM94egmJzq3o9C5XSsH.mid
#   inflating: PDMX_subset/QmdwzA2nQPDxo6o5NkXpgPabDvct9tMMgnJRaGKpC1kDzp.mid
#   inflating: PDMX_subset/QmNY8FMYxM8nCoGsS6c8d9MhSK5BkNyVBoqgL6cFTE9DKC.mid
#   inflating: PDMX_subset/QmVCFV5nWs48NWiqLfRobekAwS7ZwgjRBBttsSkaBNQ927.mid
#   inflating: PDMX_subset/QmNN3Qx7rheqdJtRTUKshANpcPb4mB86M6Vsih4QS62cmT.mid
#   inflating: PDMX_subset/QmUNS11YMQR9NYxzG4K9dwcw1g8YAocdwMYzaCvPpWjq11.mid
#   inflating: PDMX_subset/QmYTJwJ2Yrdactq466DjqbE6Gv256p5UykEfh2VsKmg6Kd_0.mid
#   inflating: PDMX_subset/Qmd5WQtL7Ltt3NrHAY3pdubTWyV6J4orGNz43WYX6Sxjm4.mid
#   inflating: PDMX_subset/QmSuwGvMSeD38fvG5DH77gKnposoupXmVBwsWYn9cXNfqf.mid
#   inflating: PDMX_subset/Qma3ah2ruPtnR8Yv1YH7Aep5vS2NhZbtpXAV22W8XXp6vE.mid
#   inflating: PDMX_subset/QmdksHo8D2GLji1mtf6bXohGc4oJapEByh14CnrVZ9K1mD.mid
#   inflating: PDMX_subset/QmfCxJ9VwicAz2YzNftRtp2xuBJojLtLkjsUhpBcAhqnwh.mid
#   inflating: PDMX_subset/QmUvYNvEGyWZsXmKSAhXfHb8vDXfmNhfguHYj5xvwBcWpT.mid
#   inflating: PDMX_subset/QmaxGgn6ezazdMgWMYtap9rgdi7ifWwvso9ewVYoQcssV9_4.mid
#   inflating: PDMX_subset/QmVFoqPMbDEu7i7jsZbAX54LZ61R1L9RLPL1kvVbYGrSZJ_0.mid
#   inflating: PDMX_subset/QmWNhq5Qws33wbUQrxJ1HB6dTTGzD9f2TdXkEF45uYKBqi.mid
#   inflating: PDMX_subset/QmV2YWmikceqxbeij9EKvW62LpLJ6wEK8YhcZHks4PyWnx.mid
#   inflating: PDMX_subset/QmXjVpQk4a1UmfUXSw7sAC7d3uHYsMU5ZCdPkBEfPCz9H6.mid
#   inflating: PDMX_subset/QmTgN7m6sauHN2mpoC3RMF7w5Hrr2U9pBdqd1LEJrnWKdC.mid
#   inflating: PDMX_subset/QmXHtArRpHpFcXm4MJfMo1xk9NEQCCRYLSK3vdQbHXJZM6.mid
#   inflating: PDMX_subset/QmegUQcmckNkRyJYz3GZjqGbSuuR6zG1HjX3fzYfjypWeS.mid
#   inflating: PDMX_subset/QmcxYaEXV7FRAaHGSJLACkC6SJ3rNsF9trwTKAH9nRJroE_0.mid
#   inflating: PDMX_subset/QmNvnrnC9aycpxdWKgLj8casrRTNDxgDGCApzpgs6cRcsh.mid
#   inflating: PDMX_subset/QmZAjSSdusGG93YcG13n3hNFLXEJJKbTCtrf91wa8c9QHA.mid
#   inflating: PDMX_subset/QmWy1nXgnqhzvhXPP9gn6JMSto6v5DiVtyf9e1vY3skAfq.mid
#   inflating: PDMX_subset/QmTUiksiRqKTVHcxFLmrR2PGnTxtpvjwzfx8VA79z3bq49.mid
#   inflating: PDMX_subset/QmaTS27RgoL7nUCuiC1UCwMPL6PTpchML5jYTqe3ZVF8Nn.mid
#   inflating: PDMX_subset/QmQ2uaJ8tZF9db9ZiXUjpTV11vdjTrXa65n3ceDYq3goqK.mid
#   inflating: PDMX_subset/QmY66Zrgwr7eLSTkttKGa8edZJ2jqpSssSXJqBTExNnoXZ.mid
#   inflating: PDMX_subset/QmWesMGS3fRxUsTzsyTLcjRsuQuPZHsLGmVwjbYieVj6tj.mid
#   inflating: PDMX_subset/QmQxFSjuWKdpbjxSeybHcWBWFFTn5HBDpKf5waRwjms99U.mid
#   inflating: PDMX_subset/QmcYxgy8iGLimriY7HsRToFo57fQ3UkZDixAfAYJLi8tjR.mid
#   inflating: PDMX_subset/QmVyJq2YLncVjCkGQc1ZBgnkKHMnxaWtMpRt6gFbC9dmau_0.mid
#   inflating: PDMX_subset/QmVgR2cZhwYWqLhcJmompA7nFKq5o7XgjkXx6ZGoK9oYsR.mid
#   inflating: PDMX_subset/QmNoynK1SLyo7DizYfKKM1nfhrA57o53qtXfgFrPu7i1Kc.mid
#   inflating: PDMX_subset/QmT1SSubRw6v7J3bRSFXcFpGRZVzGNQwSJRb4d27kp6MvA_0.mid
#   inflating: PDMX_subset/QmRLZ5CGjPdLKD4LwAShay4mDa36FoYhqVy5qdz1NCN4En_0.mid
#   inflating: PDMX_subset/QmeSTHuo333Tgp9wZvPSw9TsTCWpzVxWqdScPMrmcVPQ6x.mid
#   inflating: PDMX_subset/QmVPJhLcFFK1L3QVE3aeZBmrSqTuaBHaomEnXTN27urZQT.mid
#   inflating: PDMX_subset/QmS4QXDhbBovA4xQusoPprGLX9oKhdyse1NNm6aLVMpjPB.mid
#   inflating: PDMX_subset/QmYZSY47dsgfEDCjeoaDg5ydm91Q65jq84fj5ns98vF2ZE.mid
#   inflating: PDMX_subset/QmeJaVYehUNj7qGyCQ39AZJiuiZTnRbKaTwfo2NWHswZg2.mid
#   inflating: PDMX_subset/QmYZR3yp7NTZzuUd8tKQb8YTS2VL5bDruZSXCDbCjNjQrG.mid
#   inflating: PDMX_subset/QmNUezKWyy1K7uMeMPSpiokmwq32qk2QW5uxJHica68vrZ.mid
#   inflating: PDMX_subset/QmdgjDMV3Hdj1zw4ZV3KhMWs9o3pRpomZnhT9kRSRGzrBh_0.mid
#   inflating: PDMX_subset/QmQgqK2LqWwCD1P3v1bjSE6mxbzWoB9svHxTrg3LCj6Mbt_1.mid
#   inflating: PDMX_subset/QmRMsmMLvq4Dg4kpQhqTs75rWB84wKDBLdgHrLCAq6DJbR.mid
#   inflating: PDMX_subset/QmU2e7iaAPC2rt9C8dUe64w2J4rbccQmHCmPrKVd66nYX2.mid
#   inflating: PDMX_subset/QmP1o2affekT1XoRL8mLupLef8AMdjJL1F6phSdMuNienL_2.mid
#   inflating: PDMX_subset/QmW5D6ySZeuvehpJLXu3ieijUEd2vCd3of5aPHcAVmuftT.mid
#   inflating: PDMX_subset/QmTvVrdzkWWUFa1MXtR8areEVdEifWDR9qX5D1MB5CAbTR.mid
#   inflating: PDMX_subset/QmV5EHzQsBAmY9yZkKqbFDy6pNALN5HdMF9myh9e3Fwfxc.mid
#   inflating: PDMX_subset/QmXBLVtNTPhC5DnymUhtBwQ6g6U2pyVoXK2rWTi9337d91.mid
#   inflating: PDMX_subset/QmNugLq4o5G4MEruCq7zTqi4KcB36yqGT8cmTGRcWXwbmh.mid
#   inflating: PDMX_subset/QmUNSuo4iv7ngBW8udNaVXqtv4yGZ5FERSo4qHSJbXcksU_1.mid
#   inflating: PDMX_subset/QmSAJpnCwB9QGAGpWYHkFLMmeH9ApAZ3Tt9Mmo6io9qfDs.mid
#   inflating: PDMX_subset/QmbhNTjicHTRGJC6XEupwhtgigCjhCdieB75u7TbqLBSPm_1.mid
#   inflating: PDMX_subset/QmQVAoh3uunAkWWNJFCqBL7gRAjFSGBgRqPMokiHcvFWbW.mid
#   inflating: PDMX_subset/QmXXKbfb6GRbtMoA6xhPEsbbFu9F1vmEuEcq4Bv1jM7xMc_0.mid
#   inflating: PDMX_subset/QmbHsvdZtFRxC1guy3YoDoSUwUgFHEwxhMn4s6CXZtVoRF.mid
#   inflating: PDMX_subset/QmVGdHtEpRdJcn9QXpkqsm53KveBoBWE7LHdW7qhSYe44A_0.mid
#   inflating: PDMX_subset/QmZfvVg7vhH1vdTqDbnZUh7GfMoFE5SfXaJTfMUPmMr8nd.mid
#   inflating: PDMX_subset/QmXNxXnWMgawxKeGC1NMRmpdNKnhRPY4joZfedVbavdiwT.mid
#   inflating: PDMX_subset/QmPcKSEk92CqFgKmSYYNVb8WeLKh1Km28PhaY1zg3bZVYg_0.mid
#   inflating: PDMX_subset/QmQAxDrwArnmd3YBCRMhEh5BpeKt15UDP2bYGMucPWRVUL_1.mid
#   inflating: PDMX_subset/QmbJ1K3XEzczRznWzkgiNvP8chFTEYhd99p877TQKQh54j_0.mid
#   inflating: PDMX_subset/Qmckn3eLx5TN9M4m1SFgQc6xHNoB8fVgPqX4dwqFHDyton_0.mid
#   inflating: PDMX_subset/QmYcyYK4fVwoxEyWun6Y8Usxx5tUuohED7Vxr5Eyig7Yvc_0.mid
#   inflating: PDMX_subset/QmafgUPMqP2iWGpEoKDgZX5udLZqJ225PYR9WjRj8G464i_0.mid
#   inflating: PDMX_subset/QmdPh2PgEmMYyNiGyBEadDmjVnrhf5Qf5p5rNZWmoY3zw8.mid
#   inflating: PDMX_subset/QmetoZBzk9cYkvjechmJRs5DbkMUWqNqGCguivxRDNCu7Z_0.mid
#   inflating: PDMX_subset/QmPZMMLRxKXrdMA1QJDFTgfpQNTGLLHAJpefiBNYiTkPHS_0.mid
#   inflating: PDMX_subset/QmUi6SaVRJhqGGd3qfSedSheyMGuycpZy42aho9RbCYGtK_0.mid
#   inflating: PDMX_subset/QmTfqXQNmBFmWnqpCBsvvDcNSxmuVNWp3BKEX7VV3X8Kvb_5.mid
#   inflating: PDMX_subset/QmNaKrHfLwvjj7fXYTHJN8dk7mkaoK7fm5Ny1hzmVT9rDq.mid
#   inflating: PDMX_subset/QmbSon8L4etdhLEC5N5kyAg9VndcXLgYpKgQs8xidttqKK.mid
#   inflating: PDMX_subset/QmWuERXXzr9QAFS55stDuFTsLxZRfR5WwDDoEE5YoTPChT.mid
#   inflating: PDMX_subset/QmdfXW3a6MwcADHrfwXbhbRWgFHkWo1GruS4qJA2id7Fi5_0.mid
#   inflating: PDMX_subset/QmcpBPuMmi8JKMTJD6fxj6WZWUx4ZE3awjuEvrRGUSEzqD.mid
#   inflating: PDMX_subset/QmWt1eCxr2h1QgfpTQJPH938ZG6DdQ4U1DTrafVZUiJpbB.mid
#   inflating: PDMX_subset/QmayUZGXXTGbwRT6nux3xRopr1Joz2cQj5iRw9PWYCfTdv.mid
#   inflating: PDMX_subset/QmYS9QVWwzF4oSYqXKfPWSUNxkX4w49eVkkQirsZjkRNpH.mid
#   inflating: PDMX_subset/QmdiEgAeC4C8Q2itUo7J8BWAbr3jbM4MdYkyYVo4WM75Gc.mid
#   inflating: PDMX_subset/QmYUu3TVGg2xadY7eab8oatxoPmTn6ZAJmKtm3cVgzKyJ6.mid
#   inflating: PDMX_subset/QmRiHwZeUjvccuUP6Yq2gPAmadGosDADm5eXreZ2caKJPW_0.mid
#   inflating: PDMX_subset/QmbMoUAsqixLbaXUPxp4rjEWbjXRXpDWa698KH1QfMntCU.mid
#   inflating: PDMX_subset/QmTp59NdtPp4jjiTnDEZ2w26piabS6upiDnersDXoDqiW3.mid
#   inflating: PDMX_subset/QmdP3HxE94LhtCBH4o9Sx7WWQiyALr2EAdBNVf3UacLLZQ.mid
#   inflating: PDMX_subset/QmS1eynqFSRieCYp7nuL9x81kNMMV1QyKjBP12WuYuyKyb.mid
#   inflating: PDMX_subset/QmWnvM9xcLRaNDyV3dZvV8QAd542xkhvrgtV2xpgLr9qYA.mid
#   inflating: PDMX_subset/QmNdTYxDri5QhWJmyF725x8jN6iuir6VV9R8frCjZqnJe4.mid
#   inflating: PDMX_subset/QmfYr2UwRqRXwP83CSuGnahcAH8YC7ySExT97urCWaB2hG.mid
#   inflating: PDMX_subset/QmRN97VnDkUyrZhReeyfh2WSWFKzwpHMxuhg8s7vCnVtGx_0.mid
#   inflating: PDMX_subset/QmY9KLsn8NHp6SPnrGDcbtAEpYRj3sgVakM2cD8ncvEbKw.mid
#   inflating: PDMX_subset/QmWJa4bfU7g6P8MbivrnQnHsgG4DCV89toXuGuQctb3ojM_0.mid
#   inflating: PDMX_subset/QmRG1kqHci4b89rzZh5bVdR3HeP9qaU2535LG9bEo1X8k4.mid
#   inflating: PDMX_subset/QmSqXKwVhYadSGh63zcSsEXa1PELGUeiVyFnvXdTc17uT4.mid
#   inflating: PDMX_subset/QmQCV2HdWzbWFZaa8G9w3XNJqgVjtmDP6Enbca1DKEVgan_0.mid
#   inflating: PDMX_subset/QmUHGF6zSbBunpjLjRo1mMjfSov3nUUqSTa1r2u2AoyD6v.mid
#   inflating: PDMX_subset/QmcZuQsuoBwgo5C5GAkWqqzGPX7sNB8jkywSoumLrKDHqi.mid
#   inflating: PDMX_subset/QmbPTCNWynUb4rwvBrec2usWUc81mwgVsFF1Pu6uqfSfjg.mid
#   inflating: PDMX_subset/QmcALjCcRJCZ3mcP6r5cTBWeuGSXGq9mayx1nzmJaUPLYT.mid
#   inflating: PDMX_subset/QmbTj5RUCPyP6hhWb5tU34PLTEUgHv2jjdNYc2npRvBdBP.mid
#   inflating: PDMX_subset/QmconpAkThJq2L5B7qK7F1UPgmUmUBCAGL9C4Y3YgzfaKS_0.mid
#   inflating: PDMX_subset/QmZHEkaACaLh3xbXyNUzPotyQvmCJaJMKPYTrfa6e3vozh.mid
#   inflating: PDMX_subset/QmXjiK7VVSpwVwsK6QgZBiZt6Zvw7xihVPmFJcRVtaRYsW_0.mid
#   inflating: PDMX_subset/QmTCsGvCeViSD3uce9ndjCyYfE4ppqGjko2MHJZR5gYwgP_0.mid
#   inflating: PDMX_subset/QmPJYVqbFCbadPpmGVhjpfaAUi8PBhF4RHQgaB29rpuxYA_0.mid
#   inflating: PDMX_subset/QmVHuvWvhH1qSW4iTUkgooWcXNQjkZc249CdH4MgrLBmiA.mid
#   inflating: PDMX_subset/QmT3Pxf4X7ZdCnvgtYvnrzMofenxz1LqTeYBwfddwQfwyi.mid
#   inflating: PDMX_subset/QmY6gzK6HBcRCd7xM5ekrRRD6wYxDHwVsjorS4CjxgasFF.mid
#   inflating: PDMX_subset/QmTfUcDFwECE2KurMrhT6MMi6VBgC3Qgo93KUHaiJnX2dQ_0.mid
#   inflating: PDMX_subset/QmRz8J1TUT8U7ByL2TtME62jw9AArGPzANAQPfb4AFPeJ3.mid
#   inflating: PDMX_subset/QmPC2TW98e8JkX49fdjTxKyrzow6o8HNgdiBPjxwe7DHKX.mid
#   inflating: PDMX_subset/QmSdJcoWiDm41QiJJrwuq7P8Q9kdyRjoGLLqycFcPQWWHt.mid
#   inflating: PDMX_subset/QmUX79vinuQAtKAgnoxg9WgXLDFs3Hod9e1BShj6pvCLdg.mid
#   inflating: PDMX_subset/QmNWMVWXXZuxjTduCXYP8NEXiXYfTqxKk7e3dJjMofzJvg.mid
#   inflating: PDMX_subset/QmVzgyptv5dmhpcEfsmF34v27LzBFRv1f1EtxZQFCvp1vn.mid
#   inflating: PDMX_subset/QmbTSg6rpNU6atVMELDA6nnNQfKhNyrJU91X3KyGJZKMXw.mid
#   inflating: PDMX_subset/QmacneJJheXXwnrbd5dAH2nHnFm1QCCMd25QV22dD9gFeC.mid
#   inflating: PDMX_subset/QmQUgjwhDHvFMio4k3Wh6g7pXAQHvNWqpy9q8RVU95Ddo8_0.mid
#   inflating: PDMX_subset/QmcvyvD9W8d8Lob42VMNuFEuo2iPw9HSiyvPyEjMiANERx.mid
#   inflating: PDMX_subset/QmaTkBdLYSzDUXVWAFvp14mFN7nYoNTHP4zhuMzi3afeoW_0.mid
#   inflating: PDMX_subset/QmVMPQ4Hr4Ns2FMsdLLvQ73pETv5ZxEQ6CdXzcN5fMDXpM_0.mid
#   inflating: PDMX_subset/QmUVnK37A8AVHjVMGTvdcg3Pnb4aUGEUGFmV9ZQvbRRjUJ.mid
#   inflating: PDMX_subset/QmVcKc1usRGsmmXuUsrNnQ2YBiKA2JEpFvPUoNT5XNPGaP_1.mid
#   inflating: PDMX_subset/QmZ2RQ1Qiai2mj2pBjEcjATGEZ2truAu4ene9Appb6aG3T.mid
#   inflating: PDMX_subset/QmdEz9cnnTD676DF3c6TMMXmATCUm3uUB5cuuvmY33c95u_2.mid
#   inflating: PDMX_subset/QmS5VC5G4VgSRg8RQ3RGJGAAgxgtoyY4jz2Z26N6mSVN2r_0.mid
#   inflating: PDMX_subset/QmQB8ardzGvExoDhEnA614WhXQREcGQMGzYewwD7k84iot.mid
#   inflating: PDMX_subset/QmaTTqzTJnBEfgyZKkAi2z7Zt1zMMoFzguufEaM7YfVRKQ.mid
#   inflating: PDMX_subset/QmZ9fwP5Wc7LZj95GZk2yMtcoFZXbWLNm5fRzmnMTupEfm.mid
#   inflating: PDMX_subset/QmRAGvrCDGAPXfZWJzo4qQiSTcYovLwXbGBrQtCbMxes59.mid
#   inflating: PDMX_subset/QmY2fnyeQHfzKBwwt3cwN7EUKQuTcYE6EvEHKDQV2GSmPJ.mid
#   inflating: PDMX_subset/QmT7hkL6xUfcQZca6FZbtNwwsR7WrrQaxqupQVxCXkhP1J.mid
#   inflating: PDMX_subset/QmUCtXD2ZFGtgffiQedsepsaEKhUUh2sVbZWr1kGoHiHi9.mid
#   inflating: PDMX_subset/QmT2amferKF2SSP4qvvznWa6TY2QPiNdsbU7cZJ2FZQzAA_0.mid
#   inflating: PDMX_subset/QmQDXCoq43ykaH4k8nqRzbrxHfxkH6rNxbZp6v7URGWyVK.mid
#   inflating: PDMX_subset/QmNeCnUZDHskuAtdYjTqneCjXQrEKK4HPV7SMguJ16i8Sf.mid
#   inflating: PDMX_subset/Qmf639jsW1r7p37HShAKN62JSqvHiWPQ1BAwNUWR4V8LPQ.mid
#   inflating: PDMX_subset/QmcFyDtJ2pA1UXLupxqKXkMEBXPicboLanv6NRiwBMAK9s.mid
#   inflating: PDMX_subset/QmRafhcZ7bEpNBEFYdTgGdMHLdCTX9VG6xfJvzLxdF4YjZ.mid
#   inflating: PDMX_subset/QmPcdWHRFo9KHbdm2KBRBGb221ZgHTeX4TY6BedZRyhTm3_0.mid
#   inflating: PDMX_subset/Qma28Ey5FTsYx2tTcJFLEFaGm3hjbqf49E97VxPuy5J8R7_0.mid
#   inflating: PDMX_subset/QmPga3sFVX4t9Ju8BgLs2ymuT74Sscr95vPf8eE5Ww6Ddq.mid
#   inflating: PDMX_subset/QmTYhkccUoVsUANnmLpz7vKAwXfuHWcJsUQqn4ZSbQf8nZ.mid
#   inflating: PDMX_subset/QmYqSQEPjzzVSSYXGXunz7a7uspb6eVaTX5Bc9pCs3m3dK.mid
#   inflating: PDMX_subset/QmR3m5mPBH5snHaUpxXxX3qDzC2HDyXj8YNXihogQJ19nb_0.mid
#   inflating: PDMX_subset/QmdZqsUXtZC3Fc8TW9DSFpXwZHs3wmdoh9jGtcTxZRbtFE_1.mid
#   inflating: PDMX_subset/QmbtUnPCJDi2BQwi23HmSC13VEUDziPYj5fgoXdH61dHbt.mid
#   inflating: PDMX_subset/QmR7VBDW9DBX9XFb3M1vMRDHxXVJwzhe11H13bbgjkdc7J.mid
#   inflating: PDMX_subset/QmVd3avxYfskBQgy4tWjhbzvfLsWzc8fdwXjh8rBHXyuAk_0.mid
#   inflating: PDMX_subset/Qmb5tLYbAzb19zQjP8nKLmNASN4WN81zx2UmLKKRz1qCo7.mid
#   inflating: PDMX_subset/QmRQissQDJSWPrEKARUrTrcnVTv7ngi75D9jsTUvAG6LQ5.mid
#   inflating: PDMX_subset/QmbGJwDy5bAW781qoq9jCAA1B4c1ygEuxTq76HvE6zVtxv_2.mid
#   inflating: PDMX_subset/QmWeZXTUhU6BgxhhpwJK29jQar1AMpoTe8hjTbsLh8GWUJ.mid
#   inflating: PDMX_subset/QmXnR9YvkJ1yDFFuMmTUDLinRDHABisRWERoiv3V32WWYB.mid
#   inflating: PDMX_subset/QmXoy4mwhA9968LhSGghSQsZj4HFA924oXyGraQvuwM7zP.mid
#   inflating: PDMX_subset/QmPEM2DGG1nYsfLzZ7c57kbYZ3LpjifTJGQfGYrJS5uQR7.mid
#   inflating: PDMX_subset/QmQuoPDstJh8QU7UKvErrJcnmot5CQLXx5919dohAQVEe1_0.mid
#   inflating: PDMX_subset/QmPCKg7TJbb1b9KsTPfVAEvwdUEhQZGpDjv98GBcA5WsGb.mid
#   inflating: PDMX_subset/Qmdw7qWb9HAEmXKg1XZu2zVwxK3eT4nByqwDvdgUMAJ5Lv.mid
#   inflating: PDMX_subset/QmemETYxj27RkuJ2BYyQ8uNSVYqHDvKkJkq4YQypFwtBfD.mid
#   inflating: PDMX_subset/Qmb2AmrUHeCktMq8LWoQxLcDmpp4PiBWmhEsS8a7ca2EPz.mid
#   inflating: PDMX_subset/QmTinBoV9UVB1NWfVWShMT9T4obnhAQKbJ45vLZRCvheW8_0.mid
#   inflating: PDMX_subset/QmX6G5h5yQ7xGSqzguKWXHn4AGFifEVXkC7pSrKohpFWdd_0.mid
#   inflating: PDMX_subset/QmYdwVGJXU8DHapDqeR5atS7V4GQapJJ9fsfABrJyZMEK4.mid
#   inflating: PDMX_subset/Qmeeu8gshxEbpnAp9mYFf8tJUEwGk2ppqKeNhN9v4aKgPG.mid
#   inflating: PDMX_subset/QmbuyCZAMRqz55Fie5Lf4AGi9g9vP4JGXeGQFAvmFVUzRB.mid
#   inflating: PDMX_subset/Qma2L4Mf2HtvjFH4HkBrRhUyKZg4sFD7g1utF3X6JNLbKD.mid
#   inflating: PDMX_subset/QmWzrajrTQRUrkcingSvMgFbiYFk9cSNW3SAuz7bxBvqry.mid
#   inflating: PDMX_subset/QmTtJBG1beXiWXL37AtzjTLSYycCD2uiiADgWfStRzvNET_0.mid
#   inflating: PDMX_subset/QmY5FSdoP8sEGfj813M8fUbQwcjqRqN2ugUZMuSzvL4fWF.mid
#   inflating: PDMX_subset/QmQaSuLnMxMRi2QB2V6DB4des6kXhvJxnfSr1Ruu9A6XRf.mid
#   inflating: PDMX_subset/QmazLQupA9dsxxRsqhpH4QV45cFCpYzUQvHu1kdzw2k4T7.mid
#   inflating: PDMX_subset/QmdbG7J88szFjz8GgMwG1LoxFCz2jb6da4ZrSZj2cm2Kzw.mid
#   inflating: PDMX_subset/QmTjYSyseu5gSqy5XybVKjMp67Lzy6EFw7Vh1wgDhHYGok_0.mid
#   inflating: PDMX_subset/QmdwsSGbHL822Ynh3CfpBDVucxeqnZG6mSvYa1GLZU5b99.mid
#   inflating: PDMX_subset/QmUxHTYUNUtEkhoTRWpHhPa35g842Q8mNEuMx7zKJKb7FR_0.mid
#   inflating: PDMX_subset/QmNNpkUbj231fbrN6nN2p8aUT8udZbPCe957wgpoX9EUHj.mid
#   inflating: PDMX_subset/QmVcKc1usRGsmmXuUsrNnQ2YBiKA2JEpFvPUoNT5XNPGaP_2.mid
#   inflating: PDMX_subset/QmYQdtm6DY5YxD6pDCcRKyQoCJcZzK5GYprrbCKQVhCK9C.mid
#   inflating: PDMX_subset/QmS7hQnPeq5SK5krD8agdjrRkjLJQm1zYa7z6omfNKxSyJ.mid
#   inflating: PDMX_subset/QmRVi5m31Kcz9muzCNhkey3mmZfuiiiUazSSAeohcC8ynD.mid
#   inflating: PDMX_subset/QmVujKgUnChxEVaVU3DoTwPTVAg5BrMon1L1gczekRQ3rb_0.mid
#   inflating: PDMX_subset/Qmaw48qumhDPLWjVxQTYw4vojJbbdj4N6JiBNH9ZQCMdFq.mid
#   inflating: PDMX_subset/QmYcFYQ3xV72qCTi9wDg9454hfkfFj3HYxcRVqKp91rcRR.mid
#   inflating: PDMX_subset/QmNcXq9WCUQZUFsnxU7d9bXpLLP4Bvi3C915krTA4wJMJP_0.mid
#   inflating: PDMX_subset/QmPfUKzxvQE6Xqy9WcCLuU2fu1ko62MmocetfbBX1WAL5o.mid
#   inflating: PDMX_subset/QmS4Y3ARjixb8DkzDrrh8LEeoGhRfdn5WACEYiRTKqTBSa.mid
#   inflating: PDMX_subset/QmQ8ASnZzxRSDeySesp3Mo3g3cbAAffGiR5RnP9d9pdDor.mid
#   inflating: PDMX_subset/QmZwfpWmgkSmmYhx2sSPh8q4u5z2Xza4RU5vJXtHkCGcZF.mid
#   inflating: PDMX_subset/Qmd2X1TpFzJhCGzZofEn1t7KHhehDfcxdL4Jq69hng1zCd_1.mid
#   inflating: PDMX_subset/QmYrraMDc2Dtz6RAeNL291he8Ddkw1zS77PFEcoMKc2Dzz.mid
#   inflating: PDMX_subset/QmeMP5smFbHzYTCRZk8xZg5tLfKD9NKVU7RBMay8xWqk17.mid
#   inflating: PDMX_subset/QmYdxny4kk2SM2nke6qDXzGBxUMMLreshVR8kZFpfFtX9x_3.mid
#   inflating: PDMX_subset/QmWj9oyy5iKKM5uFuhZoDzdSo8nk3m67d7a5pgZzyMjTQw.mid
#   inflating: PDMX_subset/QmZrZF3WXFXRCaBbFvSKU1GdVTY1AvSTjVjAxq7crXRbjM_0.mid
#   inflating: PDMX_subset/QmePWqD8pknbNqEV7Ubd4TynHVmwkuoPrDxUhbxhbHoAa3.mid
#   inflating: PDMX_subset/QmbftP7poiVErPvYPuYV7F4QE6SWB7ktzSmxhuQ4FXPdt2.mid
#   inflating: PDMX_subset/QmXTThc6ckEs5goahQuhYQc6CrxkjC5yR6eobUY35sp1MH.mid
#   inflating: PDMX_subset/QmdZEXY9LfiiRyZ3dS3vSiZZPrSJ2dUgi5j5LBiGQbAf92.mid
#   inflating: PDMX_subset/QmRhGYGhZaJPqF8cYQQLSv51kpnKmvbiYNAhBHNLui2Jss.mid
#   inflating: PDMX_subset/QmPNUuYW3n1sgFN6vEMWN8JVTNGQ5Y23Nz8mCTtrGdU8nA.mid
#   inflating: PDMX_subset/Qme6Mp6EfCBJaUWW1Bi8WtaKyoWHW5Aypj3esBF2Th1wGm.mid
#   inflating: PDMX_subset/QmbMy8tz5PNimw9FkmrhmVovcJxAszELQEpeDH5hj6q3GM.mid
#   inflating: PDMX_subset/QmNyF8JpLeJ77bqtc4MJzZ9N5KTf9C4HDVSZo54hhgMgbD.mid
#   inflating: PDMX_subset/QmPnGMySbhkLjisjp3LoWJ8fDNmNvniEBbWDc5YqspgRU1.mid
#   inflating: PDMX_subset/QmUR6ceFSc6FyafHruxrbKj9pSJGtxSTu6dhcDxSJf8xeg.mid
#   inflating: PDMX_subset/QmUU7aAqBJKDeLoQ9mFz9CJFdoF7E5xAZD73ppvzHkza1Q.mid
#   inflating: PDMX_subset/QmZFUeB9NZ4dvySKxeoHzTBEkniUqnwgST7x7GczPbXNaC.mid
#   inflating: PDMX_subset/QmUoknjfoQZqjXkWNHiP8bqEodNQBHLA36KayjNDozgEbu_0.mid
#   inflating: PDMX_subset/QmRWUiVwz9XgXsDZdHRTHj4Pi6DPh6F778eMBefFvTsfi1.mid
#   inflating: PDMX_subset/QmXhZurvyFf651UmEwAt1PCBTtdgDaYYB2cKMQewvmqDoU_3.mid
#   inflating: PDMX_subset/QmYHvJZbaZ35XYGN87eSULgF5UZ5U8rsxREf5bMvFsj1Yz.mid
#   inflating: PDMX_subset/QmdqtWjHVm5ttsUqZ7jEGgJxFsA1hrRvdMpvL1LrBV2d2R.mid
#   inflating: PDMX_subset/QmPDUbaY3wWGYDxPLc5LntBe9iXZDtXAuYm92heacwfwcx.mid
#   inflating: PDMX_subset/QmRRr2JRAJHykmVkNTDQ9oqNfnfB1V28J6JrJHbQL47X3W.mid
#   inflating: PDMX_subset/QmZ4cchgRj2TQobMBZsiviAnCZDapnbCz678Py61r7eC9f.mid
#   inflating: PDMX_subset/QmVBik59YJ7neyK5DymJ2FRTp68rF5zz3xY5mc7MwWbzCG.mid
#   inflating: PDMX_subset/QmdKoDqmCToEqDsepkyFdeSc3bsHHX7Vc5DxsvTee1M9Kz.mid
#   inflating: PDMX_subset/QmTpJ8TXZDdC2TuoZLx5TUnkYtTSbYwBhMTo6AKr18i4gy.mid
#   inflating: PDMX_subset/Qmf137QUxg4TBQzvGcqjcMPrRzoU1s6LmVcfA2t3ba2Chz.mid
#   inflating: PDMX_subset/QmUrpCMzzUapBb2hR2jmUMpuxqeFpXQCpcxqWg7J2LyRCK.mid
#   inflating: PDMX_subset/QmTFtpkM8YFoKzmZYBsHzmKx8mtEixt6EeXUapjuC2UNer_0.mid
#   inflating: PDMX_subset/QmUJn9nfkNHHEQXJuXiPXutg89WdxtdhweocVzsCdUCf3t_0.mid
#   inflating: PDMX_subset/QmRjVcJTA5nS9nGyiJfSun9heC9p3mNFQR6rUHVS2XuvS9_1.mid
#   inflating: PDMX_subset/QmURf17uaQG3X7LJt7fub6X5URmcufxB4tbx22aQqwCAP7_0.mid
#   inflating: PDMX_subset/QmT1a1UqeffeYR3gKNNFKFShafrJ7JLvUVjZagv1wzS3BB.mid
#   inflating: PDMX_subset/QmYeo2MkfUQLk9AgwJJUyrpv6ibS7sctYzqDW4Xq8DfyBe.mid
#   inflating: PDMX_subset/QmXugRaJo8o3q3tpRghVGsEaNPyk2q61KM4CF6yiypjLzT.mid
#   inflating: PDMX_subset/QmPnTpc69RFyy9xtxFFTXXBC3nYC4cKi33iYtmLFcCnm92.mid
#   inflating: PDMX_subset/QmfSZaJa7yYdB2L43fcKFRYNan8kzBY3qskDdBbGTN3Q5Q_1.mid
#   inflating: PDMX_subset/QmYukGXtr9BBTfvgySWtUTo89vJyiThFgrMn5wExTTBaC5_2.mid
#   inflating: PDMX_subset/QmQS5W889u81f6S1s1EbVNDm5ekmFJ4eSKtQSZ8MkBnajZ_0.mid
#   inflating: PDMX_subset/QmNb1axKUNuEJLHm8kPwbFsXMKrGYgRcfknfCiSWky6Edj.mid
#   inflating: PDMX_subset/QmS2MJfAbqXhFZA3YCjHwWwbWnTPtqERPTct87T4ug9XMS_2.mid
#   inflating: PDMX_subset/QmRA7afQQc3rGpbUnWTkQ5cXskwYHnKCSE2uj7tz8UQJjH.mid
#   inflating: PDMX_subset/Qmabq8hgpayayrSUsuiWtA5MtKMwsVfjajd9gLJz1HhSUK.mid
#   inflating: PDMX_subset/QmTnY5oooZTaze2mTNUqmiwMrVUepYb45Ptci3yyfdjmkv_0.mid
#   inflating: PDMX_subset/QmPBtDrSkBpK6xrH7hQ8xSMXTivXjB6i1dFHYGNiYiw4pw_0.mid
#   inflating: PDMX_subset/QmbRXcwg4fTKEtB9BNUwnaf4SCa44RgibdhKyyJgRpqumf.mid
#   inflating: PDMX_subset/QmNYFenjZrD99wpZQ63NA5h2HbBD9GnZiyk4ZCyBx9vRdW.mid
#   inflating: PDMX_subset/QmTtGQZG5AiNEhWyhgba4d2AHVxnW2CGRi6o52ud4gjoyr_1.mid
#   inflating: PDMX_subset/QmXcmRxXVL4991oGJXq1R7m2XRrXM1HwtUjx7We78MZbte.mid
#   inflating: PDMX_subset/QmeCrcP4dEpDBqrfGzXcWibzSjXVoRWPgbm8ZBBrG84EPF.mid
#   inflating: PDMX_subset/QmNv7b8qTHZHyVwAUkvJgLTRgZyXK9hq5qS11oPjrXx8kb_0.mid
#   inflating: PDMX_subset/QmSWvfCqewsoiiKnxnTcRmc8SmKDTP7CZSyGs7ycASpxkP.mid
#   inflating: PDMX_subset/QmZF6pnfeEY2AEQWU6a7mnWt6Jqw3Uu11gYW5uyHPsw6DY.mid
#   inflating: PDMX_subset/QmWNJ2CQCMuEPZp5mDFpyLfG4zMEsgb1nJpidk9Wnm1ZfW.mid
#   inflating: PDMX_subset/Qmbp8WwEEftpaxCU2P9VrmBgQLZwKP8UeWYNxDanTGysX7.mid
#   inflating: PDMX_subset/QmbeL9GpVzhggWgHVjMDxd75b5L1X6VWk2YK5JmQ5JWfcj.mid
#   inflating: PDMX_subset/QmU6GXh2C9pkkcyAddDASPtLSkhsRRxKGTmHwBNLTmDGAc.mid
#   inflating: PDMX_subset/QmapKXWGWPXni7eXyMAtJMawV6bdPafpRaxUcWd7WmfnDq.mid
#   inflating: PDMX_subset/QmS6oYuoS3aqtZgPJmtEPidMDQqH19Z2MhUxY2L9RSSWTZ.mid
#   inflating: PDMX_subset/QmZCACKGs9f6UA83DjWsTYCEtaPsDdt1bJkXxRek98Kteq.mid
#   inflating: PDMX_subset/QmUGSJmjM2eRPizz4qANavSJE7YeoPJUZayrxF4AcrWmqg.mid
#   inflating: PDMX_subset/QmYWu8EcPC7V4gtXWJoJVUXWnihtKo77NWRXQ2sjRGdR24.mid
#   inflating: PDMX_subset/QmQBadig7JWH81AxGE8d6JQ76AwfY8SVNooDxsbLv62u4z.mid
#   inflating: PDMX_subset/QmepbuHUs28UfxkBZPJ35EGtsfqgaNvAdhrjpB5yhwfHsd.mid
#   inflating: PDMX_subset/QmeycYhxF6ZKhhht3oWtFL3NXxARTKmmBfQCwC2o84S8ht_0.mid
#   inflating: PDMX_subset/QmYqjQrTQVtipPPCUEFFyUpDPfmXTSU8K8uygukChpJpqn.mid
#   inflating: PDMX_subset/QmR9dhbQ8ab2YWGViVMysZrCZUT2j49pFRVBokjpGQWd4r.mid
#   inflating: PDMX_subset/QmerQSKjKUTk1Q6HxXcU25DfkdbkWVvRSsLp4JtBPr8LYn.mid
#   inflating: PDMX_subset/QmUz8J8HKwVxRVmw5SXQ9Yt8ivaYHQhGbT1FC2bkPEq1qR.mid
#   inflating: PDMX_subset/QmaMJ5aNoSftHTtj3eSLjJfF2E1e9TDLmrFKGrLQYSeEXx.mid
#   inflating: PDMX_subset/QmXU9LMXNsoCQC7EkQns8KAqPVQFZpJRpp8iSE6dmJn7i7.mid
#   inflating: PDMX_subset/QmUCo6a4RLGNsUsFJ9swQDtmx2Cb353RbAjXqKk3ANo1ub_0.mid
#   inflating: PDMX_subset/QmUY7LkWMa3C6TbfVFpRh3vnNaz9JaazsZvw7M6EzHgXjU.mid
#   inflating: PDMX_subset/QmPtnFvtRjqA7NSbH83KRvhrHgerUiaTa3sq8FuUKJ89C3.mid
#   inflating: PDMX_subset/QmXyEuJQouFWpJabY7oCuCJ666kn2wYNqiUQ7c2UFE9w2s.mid
#   inflating: PDMX_subset/Qmd3ZW2Tofc76RD36C9pBCEiWsvFFaAGt8smhoozQoqLT4_0.mid
#   inflating: PDMX_subset/QmeDASZpXqFsQVCBLAEk9ZzVCmGMpcXMdJfMAtk33WphmV.mid
#   inflating: PDMX_subset/QmQ4YDvyCfk4ora3oAJ2h41463eyjuxAMDKwuNohdxA9in_0.mid
#   inflating: PDMX_subset/QmaGcxio859zsQBEhX6zGZcgUZ4onAJCjxEN36fU3L8NBg.mid
#   inflating: PDMX_subset/QmURUTapQ74VbGDGeeVyVJWZFvPRTAcXDZpeFNktj1buJ7.mid
#   inflating: PDMX_subset/Qma86E6mrF9VNDaHfTD7KzuRGWeZ1kRy8UNDTgsruYu5bR.mid
#   inflating: PDMX_subset/QmQbjhnWZxAqYPREpyDxHhMMZKAzL7StVJbmvsf9UQCxep.mid
#   inflating: PDMX_subset/QmYGAfk338h4GCv6uzrkEAPV63MpHMrLwJjfk61tKogdPw.mid
#   inflating: PDMX_subset/QmR3UFuDr2w5ZN61A6M2vmseBLDLY6zeBJfBQ3VUvUVxGV.mid
#   inflating: PDMX_subset/QmQKMtivQF9mgk7DvqnpYSNnTo9SgxrCDg9KoSuFmturKQ.mid
#   inflating: PDMX_subset/QmahQ2mYwCTL31VMYZGTQewF9dMHima6K9i9HNgQ5HHJ1y_0.mid
#   inflating: PDMX_subset/QmUJaRvCSjZJja2PEwd1TBgMNtZA3uofnNC3Qdpj94CRUM.mid
#   inflating: PDMX_subset/QmRNZGPxjSzEcytJZqdVknjHEdDZ2aktPb8Q8R6y9u3jq7.mid
#   inflating: PDMX_subset/QmV7HZXfXKrvsrYYd2vD41iSxemkt5nM58oRURntzPUTdd.mid
#   inflating: PDMX_subset/QmctFy3ZpRgsaRBVaTYAGPY2F8Qsr1jDsMBBjn6apmEndm.mid
#   inflating: PDMX_subset/QmZH2Pg4TUeV5KVU9zP8n2nDumqExYM4YkoN5wbr1ZHqLR.mid
#   inflating: PDMX_subset/QmdcnTKp1Y3ghKtwWKeLgY1BVBPjQ96rciwv6k7HSxXndo.mid
#   inflating: PDMX_subset/QmZMXbztyJVWNbyYHMcKyd5nKbfnoCM1pMDM3zVZA5NCDJ.mid
#   inflating: PDMX_subset/QmXfMt2oZCfnf4TjQV3Q6ECxpqMQMWjLaBxLst7WB79AxQ.mid
#   inflating: PDMX_subset/QmSvfg7Tum39wYmThEiPMMVX1x7DjxYjZcewiM1xTBL7XC.mid
#   inflating: PDMX_subset/QmUmSTDpwG6s1fi4cLyCqHxEfunpUKBcaERAYdTnAGyfpH.mid
#   inflating: PDMX_subset/QmRxbyuejxeTbAfUBcjXgYVeEg1LJNExLraYK2c2Na1YHq.mid
#   inflating: PDMX_subset/QmaGycBb1rXtwGp7DRNEmQhh6Avbhcj9F1GhKnV3uqYVvF.mid
#   inflating: PDMX_subset/QmPrp68xRfev9kQgbXwxGgA4Dk3Eddxy1T9rLQbF9dHvVe.mid
#   inflating: PDMX_subset/QmXMcKpB2ybpYDRQY3G5kJbhzMvjuxzqiyb52bHCGTeGa7_0.mid
#   inflating: PDMX_subset/QmNYCHgHrXia8UUykx5WMdkt4h4VczuapEY8mmynaXqyrq.mid
#   inflating: PDMX_subset/QmQ9Mcqj6Vx7mR1hwi5SXj93DfAQTTSZokRXhfGNNZLWXz.mid
#   inflating: PDMX_subset/QmVzWaMGASWrF34kDqdMRGBujBe7tBfHcdRqgkN1LX9Sy8.mid
#   inflating: PDMX_subset/QmZPSck9quUoj8aMvg1wSKcvH2kd9k7z7rcyyrMwRdgWxR.mid
#   inflating: PDMX_subset/QmP8K3JWpdMkwkAfG3BAsUS5vYwhj6V1v9UMzrLG1crGuN_0.mid
#   inflating: PDMX_subset/QmeavwgbtChPpQJANV7v4nuUdgUVHxt87M93S1GrQguTsP_0.mid
#   inflating: PDMX_subset/QmciySRwioSyEAwZENhh5w1wAyyRQrEnsLNGf3PXCHDLb7.mid
#   inflating: PDMX_subset/QmV4ZpwZ97hFqRAcu5MEdM9tpUgQqqwdm5GxUZ8NJ4EA1a_0.mid
#   inflating: PDMX_subset/QmQpE9jS5ZR5PgXJ9ZJ773RriZ5nDFrxdMdNmvDsEULvNj.mid
#   inflating: PDMX_subset/QmR7uFDdAbW1Pdrrp3xDC7Yugb3F1Ct8cgRuP9Aj12dXYC.mid
#   inflating: PDMX_subset/Qmdq5CAagdxNT44rVCY69v3xmfHzTkpiBgNUyGYfQ6AXyV.mid
#   inflating: PDMX_subset/QmRwU5HJ4m4EVdRwBeY9jy4iu6qKyKTHViLjxcyjKSN5n8_0.mid
#   inflating: PDMX_subset/QmNUvvKhrjBokfsEHkQdsoG2Z1m5vVdMpvfKdkhFA4LR5r_0.mid
#   inflating: PDMX_subset/QmPkNdff9Z1NeLdSrcfcdoVW6ch43KtPqFoJgkXrXmhnZD_0.mid
#   inflating: PDMX_subset/QmYJyDYfZV9ioHpvb4Uucth3tK6WN32gXuXUdXJmdSPwjJ_0.mid
#   inflating: PDMX_subset/QmbNcA7HiDejfMiLUnTWB3YfUvK3dgyK2xbVJG1f1hcfgG_1.mid
#   inflating: PDMX_subset/QmVpz2S94rKmJVDUHg9r5tXyYMukFMzFQuFFrtNcRJkyqd_0.mid
#   inflating: PDMX_subset/QmRQdM2GyXC4tpMweuThAFjV8cT3xvrW67ynRd6ZpQJQ47_0.mid
#   inflating: PDMX_subset/QmZTaagJ4wiKWuWke3CqReArhJh4hXCLwdWKvAu3s3YXTe_0.mid
#   inflating: PDMX_subset/QmP76t6pujUQabcKyh1QzYDbmN3jQo2VELF2XfKBCwDNio.mid
#   inflating: PDMX_subset/QmbbqjGSE4HwHmGNXbaPJ8nHUdaneLyG2m4uTVJ6vLofGZ.mid
#   inflating: PDMX_subset/QmWdBLByhtBnzow6GRTZv2ub6k77WhM8yZeuTgPyUeGMS1_0.mid
#   inflating: PDMX_subset/QmUwfqnHLf99XsGS9bufnwJNBnpwjYR4VMUe5eDJhq4kvP.mid
#   inflating: PDMX_subset/QmRLMjPkJBAybBZFoKSEKNaQcyxMahDzFUy9FsYmMozTP6.mid
#   inflating: PDMX_subset/QmYCvYWPo3pypT61HcSKcVzpdvg8hi9fmkdRoH8vSn9x2R.mid
#   inflating: PDMX_subset/QmPSm9PxF5nGyjRyeoyyFXjVG4Y7V5gVL3PwDPuxEJn5C4.mid
#   inflating: PDMX_subset/QmXPLzj4nfg7adVDXTaTkvW3WaFRQkgbhiWxjTT7sr4wZd.mid
#   inflating: PDMX_subset/QmfTrpctLrBdGSzS9wzb4hfuFQBDn6cGGaXC42Y9DgTNvZ.mid
#   inflating: PDMX_subset/QmPrd23XtXia5tGx5ATX5E8o89ukEuATWUq1q48zv6MQ8Z.mid
#   inflating: PDMX_subset/QmUnwZioWYJitFQf2ACgnJr6exvk39GSLohZMBGpRjPqVZ.mid
#   inflating: PDMX_subset/QmUJ5fwdZMuQ37MQYAxdYGVAm55EHv3XsTPgd6piigW4ce_0.mid
#   inflating: PDMX_subset/QmUh8fxYNrAR3qVyWbBj5zetqLPXrexd2KrPeW1tU1dTxq_0.mid
#   inflating: PDMX_subset/QmeUxKNv8Po7zUosiCfJwvbUQozH5Bqz8gvQXk8stD1ZNG.mid
#   inflating: PDMX_subset/QmdjjdG91rZbFddn9NEKV31aPrZ7bmALxRdRZn7hvb4WLh.mid
#   inflating: PDMX_subset/QmPvGmaK8nnJY6FFMcmUikCdEdwSJKex2gJ4gg8abKUUFm.mid
#   inflating: PDMX_subset/QmUtQD5YvZZDX9vRviUnMSk9J3XzWapLYTBesvsi2dbpD2.mid
#   inflating: PDMX_subset/QmXMgiWQguY1H6SXGpWBWzVEkmaVNnff2rgXGX84GTviak.mid
#   inflating: PDMX_subset/QmTK4yYPku8fkYRZWwYBb5M9ypHFRX4KqscV4ELVM3KKDa.mid
#   inflating: PDMX_subset/QmPfNhjUwP3aciqKjikp6zGaDrRStEwzmHxt7FMDQZo3NB.mid
#   inflating: PDMX_subset/QmPwx2GQJXhz1bno7yEp3ZxySiwqRpq4eg1FgnXUCuwzC1.mid
#   inflating: PDMX_subset/QmY4hkXtFXB974y3nbTmFVR1hrV73yFyzWeCtfmyXy1mxo.mid
#   inflating: PDMX_subset/QmNtXJZjyJBT1W7dRFLK4NiRm5p5LwAmDaPhafaynKA1gG.mid
#   inflating: PDMX_subset/QmfUa6zi8U6kZ4n8ns3DwjB4VEXRu5LfBypnwX3vXJmkcA_0.mid
#   inflating: PDMX_subset/QmQiuVZ6ecbykzHZ6oiXpUEoxv4Ep7WUSeSK8VmnrBBETw_1.mid
#   inflating: PDMX_subset/QmeDDUHDmVqPHirTMj7iZrYqfGvE4oGS2huXTCe3CpqsuJ_0.mid
#   inflating: PDMX_subset/QmefQF4UHmwNL62cXDPHSqWAzDsYB7tyW6RYPCmQ1Jmf5F.mid
#   inflating: PDMX_subset/QmcMDjtmgiAy3GgkPQJ1wUZJhn9pdmfhGm8UxbWU6nbwKM.mid
#   inflating: PDMX_subset/QmaqX7Ms1eYdqGcuXHRbHvK3oZA91RHfQcT8RhiHVRzbuJ_2.mid
#   inflating: PDMX_subset/QmPwUeav34xVue8J5edzFDB3Q8XHRA49vEUsbXDRXtqqHg.mid
#   inflating: PDMX_subset/QmcH6DJbd8bpR1XXm87EhFZLA8LyWU336oKNw5Z6sE7w42.mid
#   inflating: PDMX_subset/QmVabmxgnpPR6RqB7TZoYiKjXE3Ep4MSKeKZAsgxsZT5ZZ.mid
#   inflating: PDMX_subset/QmbrNiQBy6eMHcyoMoxxW2ZoLNGLWgzR9bJUeK7ryBxy6P_1.mid
#   inflating: PDMX_subset/QmXauvXYnTbiEpevkyF6fHqgL2DEi2xHB9yLCjP12hawiy.mid
#   inflating: PDMX_subset/QmaDpgFfvEeUizWiQAiXCbtjkSUiNebMcpVV3yDcfad6gU.mid
#   inflating: PDMX_subset/QmeirFRun99EcYKZt15RhywMNnLHeH3WdtrYKPAVv4iG6f_1.mid
#   inflating: PDMX_subset/QmTX4b7o78Dj7ZLBYXsrbWMU3FDz2KazpjrqcN9uJ4YM3h.mid
#   inflating: PDMX_subset/QmSuNgkS3unsH1Zocr9NfXNzT8pxzVUgwcDufm19QVQxSZ.mid
#   inflating: PDMX_subset/QmXyWrBMdeF9WP5EYG246dx7QXSGUCUt6fmkj4ms8c6HQT_0.mid
#   inflating: PDMX_subset/QmZWjdHU8tu4dpspPe38dQwAJaijNNaWzVHgs8tvEN1P2i.mid
#   inflating: PDMX_subset/QmfTN8BV5htf9WA912DAhyKdmGr1fRtU49o3z6AjL1v95L_0.mid
#   inflating: PDMX_subset/QmSvWs7EmFayFyseE5fpnrH5pjWrQEnSD1hBecQKLVPPj2_1.mid
#   inflating: PDMX_subset/QmeQEc8CyDTTyHY5bwur2MSDdTSAfaAFkxEvipcBjiNi37_0.mid
#   inflating: PDMX_subset/QmbXwgLWJctTwnfZi1oftWD6kQhQfKVBRtQXGwALNjnE8J.mid
#   inflating: PDMX_subset/QmSuN4WjtsTLMXAy9wq5Z4eSCcH4qgWXmjSw5sRqbgsCCr.mid
#   inflating: PDMX_subset/QmThFYSa7qD7d6QuG4RtHVxfom14s5iFNpfYKeWYsu263p.mid
#   inflating: PDMX_subset/QmW2PuUczJVJdsBQuh8GogGuusUR6EuV543Dnfiy8ty2ZA_0.mid
#   inflating: PDMX_subset/QmSMtBQJxGPhmEgqYKRM26eRPHJ2sf6tV1dMDVBU5PUyQQ.mid
#   inflating: PDMX_subset/QmacKA3qAyjxJBxDdB2nRvAhRHNVKCFz2wmN9KrWuJ4FC4.mid
# ...
#   inflating: PDMX_subset/QmQi4kYfuu5Pdi1hXzDPBUYqAu2zuqX4z1d3RviArcfmnL.mid
#   inflating: PDMX_subset/QmUoCbKDmd81eYUJrHnKRhyLkax5wWP9H5U17Nf1M5H7QX_0.mid
#   inflating: PDMX_subset/QmcpVYR7tTCADvPRhimvMsEAwkuzhJ6pHQdJEmTnfQ13ro.mid
#   inflating: PDMX_subset/QmNgswLVLh8yE2NvVPZEzFMyX5SAX5faVTwrW1oNboUdrm.mid
#   inflating: PDMX_subset/QmTDtZzUWuEtgkVMDjWyLWzxoxp7pJgaBCnUBorZeduj8R.mid
#   inflating: PDMX_subset/QmdBbx4RNquJmBnkhrbdShDcLejK15yMMkisujfCZhgRjQ.mid
#   inflating: PDMX_subset/QmWRV9KKru7hoTSCk9K3PC7img1539KofqqwvrTSWWeVhn_0.mid
#   inflating: PDMX_subset/QmT8dz4TJ7VQoJ9gTEEuvzerwYHNVRBEQp2TDPDtQPxFAP_0.mid
#   inflating: PDMX_subset/QmfAJaayhRzGHN5o8twKdxfL3M77q95c5GtADeyJv3fDhw_0.mid
#   inflating: PDMX_subset/QmYXjs5nXZm3qc8meCr3n9VebJnBLV4E238n23voHNVdTW.mid
#   inflating: PDMX_subset/Qmd5osa5kMpnCCZb27KTRxd92zczD5UqzJFUMPigmJZ5vw_0.mid
#   inflating: PDMX_subset/Qmauo1tT7VbawYpTTeJQtXqKpS3p4sXEqyoj2pEtRGxogS.mid
#   inflating: PDMX_subset/QmP2QJnH5qg1awc6YdT8E7DJZicJtAPxoJieMf3wLrb3hq.mid
#   inflating: PDMX_subset/QmU7yUBVDqVPSEXZxfsNyePRZVtBRcmCJLW4PE52teYpeM.mid
#   inflating: PDMX_subset/QmZy1Pq6exXKoJfwjCvzgR1ZUt1NtBasfDWvU3kMv6CnFV_0.mid
#   inflating: PDMX_subset/QmaFNSGAZeZjMju1pMtWn8892Qioq6gvmJP2DJTw86SbnP.mid
#   inflating: PDMX_subset/QmTjn4qUJhokVREgt1t8GGfwMHcnkpp5x4a6yaPjFSGr9V.mid
#   inflating: PDMX_subset/QmQtik5JXZL5iwsPQn89pqTyMVhfkbFJzahvRNFBixoFvF.mid
#   inflating: PDMX_subset/QmRZBn2WbJNgcpZsZqg3YBp5uCqh8Zo3y9QW8i87HwKu5n_1.mid
#   inflating: PDMX_subset/QmbozBfZqJQKrq2mPhuPcWgaAHCxF38RWSJX9M31tMEWPs.mid
#   inflating: PDMX_subset/QmbJ5AvWKax6jeuzhe7dnxXw2J843zUPudHLLRNWHjGuGg_0.mid
#   inflating: PDMX_subset/QmS3SbSafXMXZctyjYKCqG214gLVfbTjpMSX9DR9uV9dqP.mid
#   inflating: PDMX_subset/QmfMuXpRdnGqhqkcJjyGUuPtYHvEhSs26zc8dXE9tFHL7s_1.mid
#   inflating: PDMX_subset/QmP7wefH7g4V4MAB5DgcZQME1HdgF7pqnVAMAm2xQBNN1H_1.mid
#   inflating: PDMX_subset/QmPNjj6chw4XRM9hUvZ32EQ9RxSozkRetHkS8TinESgDdL.mid
#   inflating: PDMX_subset/QmT4LdQaW2ZCr5k2pz8i1GwyMHkVqQa4PC6RMnfg4dVPxq.mid
#   inflating: PDMX_subset/QmXs1xk3fws3yyhuD4tnWrv4ztFP6LQhyFsvrzq9ktiQxe.mid
#   inflating: PDMX_subset/QmV6gHGYYkMLKuaH4CwoTWPfvJ4N4kzz9BggZCRQR15ict.mid
#   inflating: PDMX_subset/QmcU6znpYZpixazgkUm6DJ4VTsp5rTdExK9Vt9vzpdyGtc.mid
#   inflating: PDMX_subset/Qmc7USnECN6drfK62NcEvGapk4CDE4NxvZMLi6BuYkh1xS.mid
#   inflating: PDMX_subset/QmVtyUsf8LvCDcHhHpSNKmcAhRAGzEqncEbdREUUEx6bvH_0.mid
#   inflating: PDMX_subset/QmShCAFTxXzoQkqRsFK7Vw1hyy7p6ni69kxHewRMkkjG9E.mid
#   inflating: PDMX_subset/QmR9CszoTzsiitWeUj19FCX1453jePGvHU6CdzAt7XrLiH.mid
#   inflating: PDMX_subset/QmbfA2MNqaveSwnmJyJe98njb4Gg58XB3ExwsaRqfcij6g.mid
#   inflating: PDMX_subset/QmerWn7CiF4KUA1kmLRANwki3E4wkjQKkyLAfF6Q11p6KJ.mid
#   inflating: PDMX_subset/QmViyUkJteZM3HNvs1fZSRiQdJe5oc7eg8J39m27qRrjwq.mid
#   inflating: PDMX_subset/QmWv6dQMozFBKV1kKPHKmxquLq8YKo59jYSEQQFpbY6T57_0.mid
#   inflating: PDMX_subset/QmPwoxSGJK9EkzJLyK2eh6U3mRBf7cprcd27RBurLTex99.mid
#   inflating: PDMX_subset/QmYeYZtC7kEqDrDtu2NX87YrVfSVY2tJa7QwA5dhk5dBFZ.mid
#   inflating: PDMX_subset/QmUzyzVJpETY66jcpvoRZEZZeMbUH9stie9pi6rYr7nxNS_0.mid
#   inflating: PDMX_subset/QmeLCXdBxgJrAYYfujCfcgEhaV5R7HwA6JiekVSSPytaC9.mid
#   inflating: PDMX_subset/QmeMLPbYdUL1eC7yR81BXccpcLB3jXKyMMWZRJwK5gecT5.mid
#   inflating: PDMX_subset/QmXxofmi8HU32QUTBBJnkLdpYRczqcZnkgKfUc9iAA2fnC_0.mid
#   inflating: PDMX_subset/QmPvHQFFUuQizEFufNujQPQwahVVhPY7sgkxQdoT3HhNax_1.mid
#   inflating: PDMX_subset/QmUvaqF7iz4wZyKi3BUT4xwVhuD3chYTu9aL8VeLMprPUB.mid
#   inflating: PDMX_subset/Qmf3mu9rApHtt6ianUgQKT9MMuyLgaxFsdmc2RGRrECFPJ.mid
#   inflating: PDMX_subset/QmT6epShV9FTCCvJ3wNWNpAA378FCmxZAUBcgtWXLcSs3A.mid
#   inflating: PDMX_subset/QmZhM5X7UzAyjPaHbqUeH5pqZjr7u5KDEJVhLVqRme3oQm.mid
#   inflating: PDMX_subset/QmcQyhoR5j6J4tYYAUL8F1thxUcdRqAjhG2EARx41CkNs7.mid
#   inflating: PDMX_subset/QmcSCK7GAH7ZnGihixKGtiCS5489cQDDDYsov4TSwFKfDP.mid
#   inflating: PDMX_subset/QmTb9BdR8ETgdTq8X8eTcb2NKdqtGv5EYq5iAHeZZoQqLq.mid
#   inflating: PDMX_subset/QmSEs13FuwMipPwBM6KqHr19Uozp5F27NPg6YrboDCReLK.mid
#   inflating: PDMX_subset/QmcroR8LGiGLcEimpRqNJDFGDHNptpYn8WFVt4KtPrzYZ5.mid
#   inflating: PDMX_subset/QmbJypgP6rhWq7s3aSyRpHb67crJauKDJiUAfqGocnKFW7_0.mid
#   inflating: PDMX_subset/QmRFsNiF3fkwHbUzuNWLnQk94nDFEj2tgexygHDzCcupSg_1.mid
#   inflating: PDMX_subset/QmcCCGgspP6iKehwMeUY6SaHhQqE3zSAhS5XPyMP6gmrXu.mid
#   inflating: PDMX_subset/QmXjJBUcPPun4yTMg6DsUZcQVtgnD432Tb2t8ro1tsXye1.mid
#   inflating: PDMX_subset/QmeMDVD9MoRALs4h6RwjC2P2WgixiddNtu6Ah6uzGUrhQR.mid
#   inflating: PDMX_subset/QmRT8kiuh45EtkjSFBKzBBD99ne7xJB1vHoaStRUJuU7Y9.mid
#   inflating: PDMX_subset/QmRcsWAQMizd3iRnjGFhmSoicVFLPxWAnwoUEK7vAvr1it.mid
#   inflating: PDMX_subset/QmaMp1bQMD78w36pPc2kdciAXPrBqV84RkD526N4Lwys2B_0.mid
#   inflating: PDMX_subset/QmWw5dJWRnwU9cov7GyQgLsMmUa8RkQ6LZ89aX7HxCnbEe.mid
#   inflating: PDMX_subset/QmXmxURAtwwL9mrGj89b4WRdW6QMYPGoG4vbEtKZc87kM8.mid
#   inflating: PDMX_subset/QmVjTHZJ45rXaNzhZNuSzbZFP5GMZu1tdh4TC1UV5aV58b_0.mid
#   inflating: PDMX_subset/QmSM38mjmAYwDr6vEvzCYdHet95f6PZe4DAN8XJVtkzXBY_1.mid
#   inflating: PDMX_subset/QmWbAKnMAeJAB9RuqzQ6uSLcHTrLJfpawf2VGP6GEtPUxb.mid
#   inflating: PDMX_subset/QmVvx3LuGFuyzkW158knYHqxF6G3nSnWjT5nRkeAdknJLB.mid
#   inflating: PDMX_subset/QmbtxNgrJeBxn1vDKGCekC5bkpdiXQzjCfkGFzktv8iofM.mid
#   inflating: PDMX_subset/QmNkYpeKgmBLnAd1V2sYkJftRmcieL9qqDmeNEC2k3xbkR_2.mid
#   inflating: PDMX_subset/QmVZQodCykohqheoERpUd5jdbQcacAQdBB6CAdRHZyxenC.mid
#   inflating: PDMX_subset/QmdscJAyiDTuY6hsBGK4VNg6yJ2anpgzn1BSsZkSFPyE6c.mid
#   inflating: PDMX_subset/QmWN4cnK6AtHcsFMqCu5dANBD7N9smmY1xdREv9LgaLQQY.mid
#   inflating: PDMX_subset/QmcU2XNXnB4JoXjRQ4wzZeFNcnT2cNV7KK4ivR9ryuSkfS.mid
#   inflating: PDMX_subset/QmPWvjAtan13ZQzv5fx6xzCDwDdKNy4ZNgChvYxy9wwFRJ_0.mid
#   inflating: PDMX_subset/QmUGQL8H1CuWzCQdK1jLPx2Vg6V1t5RLCYaapRFEGVQ3kM_0.mid
#   inflating: PDMX_subset/QmTHWh6LJsQ6ZtSZn699roY3uopy6DQgxfZqaNgd3GyEFu.mid
#   inflating: PDMX_subset/Qmc4berkEiJrDQEcr9Ueeieu9TNPUpoVkX7te9UWDxaqek.mid
#   inflating: PDMX_subset/QmegLDpiKzwmFUyusRTs4f6rzzDD7vu77AJedVCHFrXiM1_0.mid
#   inflating: PDMX_subset/QmeudwaPwdtsnYG3HgmCC1cj6WFSgQLYkdSniKrgZi7E5E.mid
#   inflating: PDMX_subset/QmZfMGLMqPoYhdpkRNpm3WRkASbLb5jGJxVRUTt8giJCYN_0.mid
#   inflating: PDMX_subset/QmSrxKLafQdYpnPF3kDLrEXj3JqRAH1yLpGvYf7KayHkSC.mid
#   inflating: PDMX_subset/QmPxuomx2NMXjyrXTcbXiVharjmm7C9t7P7dStFArnZsvw_0.mid
#   inflating: PDMX_subset/Qma8ehWWiN6y6H9rEBpyZmQAJisuVySAgW3z9cFYSM5enK.mid
#   inflating: PDMX_subset/QmPK7P2L8zzm8HTAqogZqWunhNTVs4oXwW6jCZUuf3XQUN.mid
#   inflating: PDMX_subset/QmNYdrTK2buMqeHyKGoDtQdjNDquNyJtSNJhnmEQaEmBCX.mid
#   inflating: PDMX_subset/QmWF7SbK6Xr24gnCGbk9MYdL7SdV8RStLx1W1W4wKuLLPN.mid
#   inflating: PDMX_subset/QmZDZHjy8TD7TCaASvANkUWkK4QPa2ddLtJ9sQDXBtJeqN_0.mid
#   inflating: PDMX_subset/QmWxA4ktkKabEu52ErxuN3xSA6SymnJuXaq9akKosDv9yz.mid
#   inflating: PDMX_subset/QmVg79gT1svH6vBo6RGo6w956KdQHhMng4p3uvGf1axVxX_0.mid
#   inflating: PDMX_subset/Qma8zkHYb8mytNKzEUhrxUz5K4GocCB3d32gM9UhRDo6hv.mid
#   inflating: PDMX_subset/Qmb6HcwfDmL6Z2fopkQ9CoD8US1oh9ME6efKew6Hp9Quqb.mid
#   inflating: PDMX_subset/QmWYyvb6DVUKBhHsR5RdAAudG5tM5rFxUcWzdJSy1d8xWr.mid
#   inflating: PDMX_subset/QmTg8oRW92wQxnfvbeWn3UpnDm48mRKULNk8kvwYzh9C5B_0.mid
#   inflating: PDMX_subset/QmTh8neSKnAcaB1o9C9tEXy4DQRVZFQRyDKWAH32Qg7Dzp.mid
#   inflating: PDMX_subset/QmUsgNroVVk2WMahZVdng1KK2xTKjJKb8wr1grmnjehfy4.mid
#   inflating: PDMX_subset/Qmc5HDWUPsyfRSQtW2AUT78iP7vXPxNKds1DeBmj8pmd5J.mid
#   inflating: PDMX_subset/QmQ137zb5nrBsu9tw6RqVo783YY2y51xX1bnWT1bh2LD34.mid
#   inflating: PDMX_subset/Qmf7cNfRGVuepzgkWUR9Cv2kVN5njZ6dHkhhKQnADsx5Az_2.mid
#   inflating: PDMX_subset/QmTvkRsvvFPUt8xr6okxr6WFk4r2SnsMDZXbVjKgvjqrJM.mid
#   inflating: PDMX_subset/Qmbzu6oYi96suUbDQ1wPksEvQ9qkgb4cPvpseX62QMeSfq.mid
#   inflating: PDMX_subset/QmSLbnaxzLNsFhUx8b8K9nXBsFN6rNX664Pu1NGYZJLFxx.mid
#   inflating: PDMX_subset/QmPpZB6Gth16gf5zYMG99Ae2HYD1HTqzsLHx4TFhk9eN8x.mid
#   inflating: PDMX_subset/Qmee1mKfpK743VPjC5RmByBc1DQ84F6CATLGzPJhTfWb7t.mid
#   inflating: PDMX_subset/QmTgQ7e3K9pCP3QFZV993471wjofMv9ov8GFpvwMMoKkXx_0.mid
#   inflating: PDMX_subset/QmRc8mACr5XRVn6iMq1Yu3SLsiNVNnVw8VjFBEVsnrmQ1D.mid
#   inflating: PDMX_subset/QmXVA8xiCdp9Lr356aVxjqQ8yjuNasfvmWUJqKp8QtQ4Bs.mid
#   inflating: PDMX_subset/QmR1EBuvqY7U1zFKbBnXGuqwTufpe3YDNAMRWasFqvbmQX.mid
#   inflating: PDMX_subset/QmcerwHfjrULdEFz1FjQwqRjZfikP8D4mYcRW2kxMBctdU.mid
#   inflating: PDMX_subset/QmVrtBXHn9Tnh7JpnvJDeBUBnYzfmu9Uyt9gsc9Unhks8g.mid
#   inflating: PDMX_subset/QmPugsLSAs6zB45MfYgS73Qij33SjLCHsrJZQz41XceBfW.mid
#   inflating: PDMX_subset/QmcM8C2wdHBqHyoBgXx2MgkBfVxdAQ1RcP28v4vY91KYVM.mid
#   inflating: PDMX_subset/QmX3zdock23JYSNMj5Kr3zE13yAXfwUf5v7fKmLJCYP7eA.mid
#   inflating: PDMX_subset/QmcrZpsm1qCmspJAnoq4YKjV9Ljd93cWqgVx3YJq9dVR6F.mid
#   inflating: PDMX_subset/QmTaUK2AU9DsZ5ZvG9bN6FENGJxCVsSmifvxsivkubY6Zz.mid
#   inflating: PDMX_subset/QmP4tZvhNhttQfnGBPfHEqARTLtbTd7d2PzLFEs8XBMopM.mid
#   inflating: PDMX_subset/QmQa7PJjf5H3EVXgnDrVRcGmwPvMnAQcarD9RfT9SNSm9E_0.mid
#   inflating: PDMX_subset/QmZq8P6jcPscPmX54SytMhyPiKmrqLotLbsZAi3DTJcGYM.mid
#   inflating: PDMX_subset/QmckneEq5W5A6QKRYLLTyPza558xS8vMwourQW1ej8sXhA_1.mid
#   inflating: PDMX_subset/QmPs7ovAkhXaNRVdXdVqRY41hdCXtv5eJk2fnEP9gYj8tr_0.mid
#   inflating: PDMX_subset/Qmbez2cyuoZzstbLMG8uyaBaWxw65gHpyqXSjDiiv86YnD.mid
#   inflating: PDMX_subset/QmaH8t2AtFEbcB9CZknpcXASaxtvZpnWy5UjhqNZTTkQay.mid
#   inflating: PDMX_subset/QmSn7qnbGFztijDoV7XYmogZcKrpoX1qAVyUWY6X1n5nya.mid
#   inflating: PDMX_subset/QmVxs7C1pkVnruupsQzDWjAuUsGTWs2E6nsEuU8d2bNBPG.mid
#   inflating: PDMX_subset/Qmbm1tporH8LXXM7ek1UY9njocXbzqiHbpnsuT58XVRhUi.mid
#   inflating: PDMX_subset/QmRjqcoGdbEeJuUepZF2AxisnEVqZTS46v2LPqZH3kvJrA.mid
#   inflating: PDMX_subset/QmTb3sGT9ZdpoDEXf88JswT7uhtgJsrA9Lh1HBcizHRZCN_1.mid
#   inflating: PDMX_subset/QmTdKVhe9N5Yb1Ktz4gkjbFbKMUZwFZKjcz6rKE4NNE4yM.mid
#   inflating: PDMX_subset/QmTqQ9u6LkZbnb9WZCHMAfb7zenFXXK5qYSZKHPkpQxAJe_0.mid
#   inflating: PDMX_subset/QmdNevV76M79W4K6mEcjphdZEWDmiSwGYtiWffsnwUUZaE.mid
#   inflating: PDMX_subset/QmTDLsWQpUZvVZBT9D8NoohxDYG3zQKNiDZiU9Ak1VCZZe.mid
#   inflating: PDMX_subset/QmU1sBveV5bjPeHfYHZUGQBadshVg6DEitVDZeBgbBEuFk_0.mid
#   inflating: PDMX_subset/QmQknH68kZ6YmxGbJy8wUae9k1CMzi13PYA69ve9eRVhXD.mid
#   inflating: PDMX_subset/QmTfFZGjK45kB8KvtkwMmHyv25SkUkECSxtWaKzqPYUBtk.mid
#   inflating: PDMX_subset/QmSazvUUghNHVDEj1DjoXLJLQBeepFoFwKs8s7QTccTNAn.mid
#   inflating: PDMX_subset/QmNd36Er622B5KX5Dqk5YDG9SF9QQsrxFzyyrRmJMkC1T1.mid
#   inflating: PDMX_subset/QmPGRDXdbY93H1T5M7k7HoiG5g6zZxz4DsimEssBvNKiVG.mid
#   inflating: PDMX_subset/QmaGoJDbJEYL6m2PmFJ2Py6oahNXa1fdAhpLW98sG2Engy_0.mid
#   inflating: PDMX_subset/QmduZB84cKMbGLgihLDjW56nUKy2Etks1s9qVF6bMc2Dw1.mid
#   inflating: PDMX_subset/QmSjUwLmE7ND8QwwrSEgAHKbDL9c5reMwVe7rFNPaapo9R.mid
#   inflating: PDMX_subset/QmcjHztakwxzx4gieMPf25jzy53TwEVV3ErP4pGoQjmMcU.mid
#   inflating: PDMX_subset/QmeTXnsb3iYTcQD7JgrYTajiEV1VDw9ikraYDWqTyUUsQW.mid
#   inflating: PDMX_subset/QmSx4zmxxkvPwb1NqjaTooCiSvhg8DLtVDYnz8fk8rQzbo_1.mid
#   inflating: PDMX_subset/QmYr5dKKUT5iYubjcWKdqYVfJ5deqa57SSiTjbvLKZMtXL.mid
#   inflating: PDMX_subset/QmTh1KRRmxL7gkvuzBfcPUixVk5fu9pCQCdarwCS8yLVhp.mid
#   inflating: PDMX_subset/QmPJQRzvz3WGLRTYe631W43UnaoQWRZzTALhbCBx9WVPoH_0.mid
#   inflating: PDMX_subset/QmcE36xFdNxWGQ4sjVMcPMkvvrVgy3SY3xNtH9WR32Adad.mid
#   inflating: PDMX_subset/QmdMDjzCMSSeTajayVZgVE7Wx1uVHLrCKiE9Q8pVPFHavs.mid
#   inflating: PDMX_subset/QmbrCiQ3XhNdnGXVeBYngiRHYL2VEVFm8dggPe8FoDqrLK_0.mid
#   inflating: PDMX_subset/QmSK8hT8FXmSaFGLnRqCvyMG2Y1MAdGNYTvqWNzEVH1H2m.mid
#   inflating: PDMX_subset/QmUGWAMPozuV3L8FN33eJuVVmLupsdQzS4iuqTFjNR4dFp.mid
#   inflating: PDMX_subset/QmTAB2CwNcyKByrh4jSwbQ38c2uqQ7R5ELxYaMfMWoV8Eq.mid
#   inflating: PDMX_subset/QmazsRjxzVsomn7pUiW1S4CyMVrkfzsASZqxUFqCR4p2Wn_0.mid
#   inflating: PDMX_subset/QmVMPv8BshUbFtY7BngtKCPThpXQbvdMt8i3j4sSguReEN.mid
#   inflating: PDMX_subset/QmVgcU5smmxNf2duQ586pX3DTxcSo1JB1PaJKZqsvDSoaR_0.mid
#   inflating: PDMX_subset/QmZC68y4AVw99Ce3QBiHhqrQCnF1jTi4v2uvW1H7Ffnpo9.mid
#   inflating: PDMX_subset/QmQnZD1MA2ZPdW5TMsRvdcP5TzdREW1r6XcrWUbmvzZ98E.mid
#   inflating: PDMX_subset/QmV5W2pzNjffck5C1GQ8pELpKGkfdaucRKYMy89z7MfN5V.mid
#   inflating: PDMX_subset/QmSvHqmZTH2dyyvB41YPAmzSVcuU3oLj8tdfnryJPVHwHH_0.mid
#   inflating: PDMX_subset/QmYpxRW3Q6zhv7w3FF12Lxab2wuVsUn9XFNm83WPhBVunW.mid
#   inflating: PDMX_subset/QmdfguaegfLPwXZR7AT6CEnc8ffmBibamkR5SDF6EvFf6U.mid
#   inflating: PDMX_subset/QmPBReV1gPRNRwPAHNKbLdMAMZQDdtZq4V9wAEhDhicmid.mid
#   inflating: PDMX_subset/QmW7sAPhCmJMsktGsfSe8jaWMEApHWLr1T8yruqD5XZFPu.mid
#   inflating: PDMX_subset/QmQDH7Dky7hxe9w4GQAEmMUxroYWTJojUR5VmiKhgj1BHP.mid
#   inflating: PDMX_subset/QmXxpfrZtdxqjzSF3C2h5c4ghXZJTiZy3UmjijQLozz1Nh.mid
#   inflating: PDMX_subset/QmSW3KkKET62HYTEP4RUuhPMu8BBt3ByRHiqNRHUFqsubf_1.mid
#   inflating: PDMX_subset/QmZJpDRkeGb7Bdt8uLMsu4ZdnUC8tgHHiXcDiEk7ngUPUS.mid
#   inflating: PDMX_subset/Qmbhu1npiKLe1HrmDsNkSzRnAP2UVM11wNFuPM2a99pUtH_0.mid
#   inflating: PDMX_subset/QmThSQhQMJqXAhUnJZJvs4UzXV6XDopLWmNupKJYPuUZjz.mid
#   inflating: PDMX_subset/QmVUhCRJcJvQ94RxmT93EPodTLKq3FXVEL9YVg8ZAU27Mv.mid
#   inflating: PDMX_subset/QmUvEyCFmjZVoQXb9j5kRaggeKaB1qi2zSpEbRHSyGhJHo_0.mid
#   inflating: PDMX_subset/QmfUixnTYpDG8CRH6JKkZxXhxv5Tnarto7c9E4fWYgKPDu.mid
#   inflating: PDMX_subset/QmchA9eDXudNrQb2i4bU6xmJkNbKuySmw91CXhBg5JzNe5_0.mid
#   inflating: PDMX_subset/QmPtAReTGPTrUSuHSBt1khmFMNBnoXvp3XLqu97ipYfa4u.mid
#   inflating: PDMX_subset/QmNpeV13pqFLTUsPxDKE9LvsM6pENjkhrNjeRJGEEn7cyC.mid
#   inflating: PDMX_subset/QmeqjD3s9Zsj1yds2mRei5kCybd1nB3rewKfpXNPz5KJde_0.mid
#   inflating: PDMX_subset/QmaHencAbibQEKCZE6bRo2H1m8rdPpymGpiB3Jw1spDtT9_0.mid
#   inflating: PDMX_subset/QmTvv4Vu7KQ9tqVyJWh33TjabDJN8yJy84N53NAAiw1cQd.mid
#   inflating: PDMX_subset/QmRJvj2iZPFcj9XpjXE7dW8CnedT1W3hzQbCJcvcfNNwcQ.mid
#   inflating: PDMX_subset/QmVzcRumf221mgrekRhzM5kJgPDmLtCScBJKdu78Xfmecn.mid
#   inflating: PDMX_subset/QmPUYnYHRDvAbr1tyJFWbb89RJsUDnLRojaQCVoaDEJBp3.mid
#   inflating: PDMX_subset/QmbQoojRP2woJEqwRzgULwtd8HB86PAQKVHWj6avUucuE4.mid
#   inflating: PDMX_subset/QmamfyfVQ3aKwy1opNBVUe6GWjbafUDvhK3NbbCeFv6EGS_0.mid
#   inflating: PDMX_subset/QmV64JJFZketmXRGXjrSDiVvrBdzFwUmqnTfVKDBi12Vt3.mid
#   inflating: PDMX_subset/QmWVgnGwELPCtoNP2sGFTb56UYiBAJo5FnCuZXbSqt8hXF_0.mid
#   inflating: PDMX_subset/QmahBWn6m9Lx8e3fLcXK2c6m4B5vJNcf8sqnBzyZ4U2QTn.mid
#   inflating: PDMX_subset/QmZTunJXGcDshtvZMWMmeszbrfMi4wFNwPdXMcGkejQtUV.mid
#   inflating: PDMX_subset/QmPoz19SGquZkxrrTssaxNZvJ72ArKPru2UVvLjoVX4BJ6_0.mid
#   inflating: PDMX_subset/QmNdy5dTKxytQBCNij3rEvvG9M6H7EmwqpF31cVxEeUM9a.mid
#   inflating: PDMX_subset/QmQhRKbTq697TiQxmqe2HtxyjhoKgMwXZSHeKV71YMrCbV_1.mid
#   inflating: PDMX_subset/Qmbwbmjvc23xZ7CJUScs9vnNvysu4y6wVB8Tzv24DXki8n_0.mid
#   inflating: PDMX_subset/QmX2mTRCnRDspUtdr4AsyZuBtDHaXxBm4Q2Ti8yFUcPqgj_0.mid
#   inflating: PDMX_subset/QmbPrM9hF71jmdm4wjRwj2dytRBdaELxmvPQMDpSeYEVrc.mid
#   inflating: PDMX_subset/QmaPgb16XbSqTCkYdVyhaU9RspgVCGCmH3qq412NeKa8Wk.mid
#   inflating: PDMX_subset/QmdabQwzakKsJR5GZmxCyx6cyge5LdH3uS9ARrQwJUHZVK.mid
#   inflating: PDMX_subset/QmWPcXA2R4FXbJFuvRa5uJg6QS8jEG7Q4kiP7sywbw9GZW.mid
#   inflating: PDMX_subset/Qmcp5ioF364k75miDda9toan25uXzpW3jSuZdEbJtSqJ9r.mid
#   inflating: PDMX_subset/QmdeQCNF74eDARP8WvDYPsui8ytTjgvy8vn6qBQviYVn7p.mid
#   inflating: PDMX_subset/QmPthx4LjtgAb4jLtUAf2t6zc9oFF3pC1bXmgxe9h5rVJJ_2.mid
#   inflating: PDMX_subset/QmcUrCHEfKSdQfVTKredbpvapHAwvCK9X16hn9Y3nLetiE_1.mid
#   inflating: PDMX_subset/QmXX4eZcPbekQJbiswLxjEYabhQaegmqr3rhnhXDnYAX5C.mid
#   inflating: PDMX_subset/QmNM5v9TuXw9FwnkhDqacVUsVJNgUG9rdSrNTanHuV5m88_0.mid
#   inflating: PDMX_subset/Qmdnj5jJ3eHr411BqJhyfKhNWR3nxMoV7GybEmWgWirssQ.mid
#   inflating: PDMX_subset/QmYaeNg9EwB6dAjMxWVsbF5PveQgWwEG9ech2PQyadRpUx.mid

# %%
midi_files = glob('PDMX_subset/*.mid')
len(midi_files)
# Out:
# 1000

# %% [markdown]
# ### Train a tokenizer with the REMI method in MidiTok

# %%
config = TokenizerConfig(num_velocities=1, use_chords=False, use_programs=False)
tokenizer = REMI(config)
tokenizer.train(vocab_size=1000, files_paths=midi_files)

# %% [markdown]
# ### Use the trained tokenizer to get tokens for each midi file
# In REMI representation, each note will be represented with four tokens: `Position, Pitch, Velocity, Duration`, e.g. `('Position_28', 'Pitch_74', 'Velocity_127', 'Duration_0.4.8')`; a `Bar_None` token indicates the beginning of a new bar.

# %%
# e.g.:
midi = Score(midi_files[0])
tokens = tokenizer(midi)[0].tokens
tokens[:10]
# Out:
# ['Bar_None',
#  'Position_0',
#  'Pitch_76',
#  'Velocity_127',
#  'Duration_0.4.8',
#  'Position_4',
#  'Pitch_69',
#  'Velocity_127',
#  'Duration_0.4.8',
#  'Position_8']

# %% [markdown]
# 1. Write a function to extract note pitch events from a midi file; and another extract all note pitch events from the dataset and output a dictionary that maps note pitch events to the number of times they occur in the files. (e.g. {60: 120, 61: 58, …}).
#
# `note_extraction()`
# - **Input**: a midi file
#
# - **Output**: a list of note pitch events (e.g. [60, 62, 61, ...])
#
# `note_frequency()`
# - **Input**: all midi files `midi_files`
#
# - **Output**: a dictionary that maps note pitch events to the number of times they occur, e.g {60: 120, 61: 58, …}

# %%
def note_extraction(midi_file):
    # Q1a: Your code goes here
    midi = Score(midi_file)
    tokens = tokenizer(midi)[0].tokens
    pitch_events = [
        int(token.split('_')[1]) for token in tokens if token.startswith("Pitch_")
    ]
    return pitch_events

# %%
def note_frequency(midi_files):
    # Q1b: Your code goes here
    pitch_counts = defaultdict(int)
    for midi_file in midi_files:
        pitch_events = note_extraction(midi_file)
        for pitch_event in pitch_events:
            pitch_counts[pitch_event] += 1
    return pitch_counts

# %% [markdown]
# 2. Write a function to normalize the above dictionary to produce probability scores (e.g. {60: 0.13, 61: 0.065, …})
#
# `note_unigram_probability()`
# - **Input**: all midi files `midi_files`
#
# - **Output**: a dictionary that maps note pitch events to probabilities, e.g. {60: 0.13, 61: 0.06, …}

# %%
def note_unigram_probability(midi_files):
    note_counts = note_frequency(midi_files)
    unigramProbabilities = {}

    # Q2: Your code goes here
    total_notes = sum(note_counts.values())
    for note, count in note_counts.items():
        unigramProbabilities[note] = count / total_notes

    return unigramProbabilities

# %% [markdown]
# 3. Generate a table of pairwise probabilities containing p(next_note | previous_note) values for the dataset; write a function that randomly generates the next note based on the previous note based on this distribution.
#
# `note_bigram_probability()`
# - **Input**: all midi files `midi_files`
#
# - **Output**: two dictionaries:
#
#   - `bigramTransitions`: key: previous_note, value: a list of next_note, e.g. {60:[62, 64, ..], 62:[60, 64, ..], ...} (i.e., this is a list of every other note that occured after note 60, every note that occured after note 62, etc.)
#
#   - `bigramTransitionProbabilities`: key:previous_note, value: a list of probabilities for next_note in the same order of `bigramTransitions`, e.g. {60:[0.3, 0.4, ..], 62:[0.2, 0.1, ..], ...} (i.e., you are converting the values above to probabilities)
#
# `sample_next_note()`
# - **Input**: a note
#
# - **Output**: next note sampled from pairwise probabilities

# %%
from collections import Counter

# %%
def note_bigram_probability(midi_files):
    bigramTransitions = defaultdict(list)
    bigramTransitionProbabilities = defaultdict(list)

    # Q3a: Your code goes here
    bigramTransitionsSets = defaultdict(set)
    note_counts = defaultdict(Counter)  # {prev_note: Counter({next_note: count})}
    for midi_file in midi_files:
        pitch_events = note_extraction(midi_file)
        for i in range(len(pitch_events) - 1):
            prev_note = pitch_events[i]
            next_note = pitch_events[i + 1]
            bigramTransitionsSets[prev_note].add(next_note)
            note_counts[prev_note][next_note] += 1
    for (prev_note, next_notes) in bigramTransitionsSets.items():
        bigramTransitions[prev_note] = list(next_notes)

    for prev_note, next_notes in bigramTransitions.items():
        total_notes = sum(note_counts[prev_note].values())
        for next_note in next_notes:
            bigramTransitionProbabilities[prev_note].append(note_counts[prev_note][next_note] / total_notes)

    # old code, this is wrong

    # for midi_file in midi_files:
    #     pitch_events = note_extraction(midi_file)
    #     for i in range(len(pitch_events) - 1):
    #         prev_note = pitch_events[i]
    #         next_note = pitch_events[i + 1]
    #         bigramTransitions[prev_note].append(next_note)

    # for prev_note, next_notes in bigramTransitions.items():
    #     total_notes = len(next_notes)
    #     note_counts = defaultdict(int)
    #     for next_note in next_notes:
    #         note_counts[next_note] += 1
    #     for note in next_notes:
    #         bigramTransitionProbabilities[note] += note_counts[note] / total_notes

    return bigramTransitions, bigramTransitionProbabilities

# %%
def sample_next_note(note):
    # Q3b: Your code goes here
    bigramTransitions, bigramTransitionProbabilities = note_bigram_probability(midi_files)
    next_notes = bigramTransitions[note]
    probabilities = bigramTransitionProbabilities[note]
    return random.choices(next_notes, weights=probabilities, k=1)[0]

# %% [markdown]
# 4. Write a function to calculate the perplexity of your model on a midi file.
#
#     The perplexity of a model is defined as
#
#     $\quad \text{exp}(-\frac{1}{N} \sum_{i=1}^N \text{log}(p(w_i|w_{i-1})))$
#
#     where $p(w_1|w_0) = p(w_1)$, $p(w_i|w_{i-1}) (i>1)$ refers to the pairwise probability p(next_note | previous_note).
#
# `note_bigram_perplexity()`
# - **Input**: a midi file
#
# - **Output**: perplexity value

# %%
def note_bigram_perplexity(midi_file):
    unigramProbabilities = note_unigram_probability(midi_files)
    bigramTransitions, bigramTransitionProbabilities = note_bigram_probability(midi_files)

    # Q4: Your code goes here
    # Can use regular numpy.log (i.e., natural logarithm)
    notes = note_extraction(midi_file)
    N = len(notes)

    log_probs = []
    log_probs.append(np.log(unigramProbabilities[notes[0]]))  # p(w_1|w_0) = p(w_1)

    for i in range(1, N):  # p(w_i|w_{i-1}) (i>1)
        prev_note = notes[i - 1]
        next_note = notes[i]
        index = bigramTransitions[prev_note].index(next_note)
        prob = bigramTransitionProbabilities[prev_note][index]
        log_probs.append(np.log(prob))

    perplexity = np.exp(-np.sum(log_probs) / N)
    return perplexity

# %% [markdown]
# 5. Implement a second-order Markov chain, i.e., one which estimates p(next_note | next_previous_note, previous_note); write a function to compute the perplexity of this new model on a midi file.
#
#     The perplexity of this model is defined as
#
#     $\quad \text{exp}(-\frac{1}{N} \sum_{i=1}^N \text{log}(p(w_i|w_{i-2}, w_{i-1})))$
#
#     where $p(w_1|w_{-1}, w_0) = p(w_1)$, $p(w_2|w_0, w_1) = p(w_2|w_1)$, $p(w_i|w_{i-2}, w_{i-1}) (i>2)$ refers to the probability p(next_note | next_previous_note, previous_note).
#
#
# `note_trigram_probability()`
# - **Input**: all midi files `midi_files`
#
# - **Output**: two dictionaries:
#
#   - `trigramTransitions`: key - (next_previous_note, previous_note), value - a list of next_note, e.g. {(60, 62):[64, 66, ..], (60, 64):[60, 64, ..], ...}
#
#   - `trigramTransitionProbabilities`: key: (next_previous_note, previous_note), value: a list of probabilities for next_note in the same order of `trigramTransitions`, e.g. {(60, 62):[0.2, 0.2, ..], (60, 64):[0.4, 0.1, ..], ...}
#
# `note_trigram_perplexity()`
# - **Input**: a midi file
#
# - **Output**: perplexity value

# %%
def note_trigram_probability(midi_files):
    trigramTransitions = defaultdict(list)
    trigramTransitionProbabilities = defaultdict(list)

    # Q5a: Your code goes here
    trigramTransitionsSets = defaultdict(set)
    trigram_counts = defaultdict(Counter)  # {(n_{i-2}, n_{i-1}): Counter({next_note: count})}
    for midi_file in midi_files:
        pitch_events = note_extraction(midi_file)
        for i in range(len(pitch_events) - 2):
            prev_notes = (pitch_events[i], pitch_events[i + 1])
            next_note = pitch_events[i + 2]
            trigramTransitionsSets[prev_notes].add(next_note)
            trigram_counts[prev_notes][next_note] += 1
    for (prev_notes, next_notes) in trigramTransitionsSets.items():
        trigramTransitions[prev_notes] = list(next_notes)

    for prev_notes, next_notes in trigramTransitions.items():
        total_notes = sum(trigram_counts[prev_notes].values())
        for next_note in next_notes:
            trigramTransitionProbabilities[prev_notes].append(trigram_counts[prev_notes][next_note] / total_notes)

    return trigramTransitions, trigramTransitionProbabilities

# %%
def note_trigram_perplexity(midi_file):
    unigramProbabilities = note_unigram_probability(midi_files)
    bigramTransitions, bigramTransitionProbabilities = note_bigram_probability(midi_files)
    trigramTransitions, trigramTransitionProbabilities = note_trigram_probability(midi_files)

    # Q5b: Your code goes here
    notes = note_extraction(midi_file)
    N = len(notes)

    log_probs = []
    # p(w_1|w_{-1}, w_0) = p(w_1)
    log_probs.append(np.log(unigramProbabilities[notes[0]]))
    # p(w_2|w_0, w_1) = p(w_2|w_1)
    prev_note = notes[0]
    next_note = notes[1]
    index = bigramTransitions[prev_note].index(next_note)
    log_probs.append(np.log(bigramTransitionProbabilities[prev_note][index]))

    for i in range(2, N):  # p(w_i|w_{i-2}, w_{i-1}) (i>2)
        prev_notes = (notes[i - 2], notes[i-1])
        next_note = notes[i]
        index = trigramTransitions[prev_notes].index(next_note)
        prob = trigramTransitionProbabilities[prev_notes][index]
        log_probs.append(np.log(prob))

    perplexity = np.exp(-np.sum(log_probs) / N)
    return perplexity

# %% [markdown]
# 6. Our model currently doesn’t have any knowledge of beats. Write a function that extracts beat lengths and outputs a list of [(beat position; beat length)] values.
#
#     Recall that each note will be encoded as `Position, Pitch, Velocity, Duration` using REMI. Please keep the `Position` value for beat position, and convert `Duration` to beat length using provided lookup table `duration2length` (see below).
#
#     For example, for a note represented by four tokens `('Position_24', 'Pitch_72', 'Velocity_127', 'Duration_0.4.8')`, the extracted (beat position; beat length) value is `(24, 4)`.
#
#     As a result, we will obtain a list like [(0,8),(8,16),(24,4),(28,4),(0,4)...], where the next beat position is the previous beat position + the beat length. As we divide each bar into 32 positions by default, when reaching the end of a bar (i.e. 28 + 4 = 32 in the case of (28, 4)), the beat position reset to 0.

# %%
duration2length = {
    '0.2.8': 2,  # sixteenth note, 0.25 beat in 4/4 time signature
    '0.4.8': 4,  # eighth note, 0.5 beat in 4/4 time signature
    '1.0.8': 8,  # quarter note, 1 beat in 4/4 time signature
    '2.0.8': 16, # half note, 2 beats in 4/4 time signature
    '4.0.4': 32, # whole note, 4 beats in 4/4 time signature
}

# %% [markdown]
# `beat_extraction()`
# - **Input**: a midi file
#
# - **Output**: a list of (beat position; beat length) values

# %%
def beat_extraction(midi_file):
    # Q6: Your code goes here
    midi = Score(midi_file)
    tokens = tokenizer(midi)[0].tokens

    beat_info = []
    current_position = 0

    i = 0
    while i < len(tokens):
        if tokens[i] == "Bar_None":
            current_position = 0
            i += 1
            continue

        position_idx = i
        # pitch_idx = i + 1
        # velocity_idx = i + 2
        duration_idx = i + 3

        beat_position = int(tokens[position_idx].split("_")[1])
        duration_str = tokens[duration_idx].split("_")[1]

        beat_length = duration2length[duration_str]
        beat_info.append((beat_position, beat_length))
        current_position = beat_position + beat_length

        if current_position >= 32:
            current_position = 0

        i += 4

    return beat_info

# %% [markdown]
# 7. Implement a Markov chain that computes p(beat_length | previous_beat_length) based on the above function.
#
# `beat_bigram_probability()`
# - **Input**: all midi files `midi_files`
#
# - **Output**: two dictionaries:
#
#   - `bigramBeatTransitions`: key: previous_beat_length, value: a list of beat_length, e.g. {4:[8, 2, ..], 8:[8, 4, ..], ...}
#
#   - `bigramBeatTransitionProbabilities`: key - previous_beat_length, value - a list of probabilities for beat_length in the same order of `bigramBeatTransitions`, e.g. {4:[0.3, 0.2, ..], 8:[0.4, 0.4, ..], ...}

# %%
def beat_pos_bigram_probability(midi_files):
    bigramBeatPosTransitions = defaultdict(list)
    bigramBeatPosTransitionProbabilities = defaultdict(list)

    # Q8a: Your code goes here
    bigramBeatPosTransitionsSets = defaultdict(set)
    beat_pos_counts = defaultdict(Counter)  # {position: Counter({length: count})}
    for midi_file in midi_files:
        beat_positions_lengths = beat_extraction(midi_file)
        for position, length in beat_positions_lengths:
            bigramBeatPosTransitionsSets[position].add(length)
            beat_pos_counts[position][length] += 1
    for (position, lengths) in bigramBeatPosTransitionsSets.items():
        bigramBeatPosTransitions[position] = list(lengths)

    for position, lengths in bigramBeatPosTransitions.items():
        total_lengths = sum(beat_pos_counts[position].values())
        for length in lengths:
            bigramBeatPosTransitionProbabilities[position].append(beat_pos_counts[position][length] / total_lengths)

    return bigramBeatPosTransitions, bigramBeatPosTransitionProbabilities

# %% [markdown]
# 8. Implement a function to compute p(beat length | beat position), and compute the perplexity of your models from Q7 and Q8. For both models, we only consider the probabilities of predicting the sequence of **beat lengths**.
#
# `beat_pos_bigram_probability()`
# - **Input**: all midi files `midi_files`
#
# - **Output**: two dictionaries:
#
#   - `bigramBeatPosTransitions`: key - beat_position, value - a list of beat_length
#
#   - `bigramBeatPosTransitionProbabilities`: key - beat_position, value - a list of probabilities for beat_length in the same order of `bigramBeatPosTransitions`
#
# `beat_bigram_perplexity()`
# - **Input**: a midi file
#
# - **Output**: two perplexity values correspond to the models in Q7 and Q8, respectively

# %%
def beat_pos_bigram_probability(midi_files):
    bigramBeatPosTransitions = defaultdict(list)
    bigramBeatPosTransitionProbabilities = defaultdict(list)

    # Q8a: Your code goes here
    bigramBeatPosTransitionsSets = defaultdict(set)
    beat_pos_counts = defaultdict(Counter)  # {position: Counter({length: count})}
    for midi_file in midi_files:
        beat_positions_lengths = beat_extraction(midi_file)
        for position, length in beat_positions_lengths:
            bigramBeatPosTransitionsSets[position].add(length)
            beat_pos_counts[position][length] += 1
    for (position, lengths) in bigramBeatPosTransitionsSets.items():
        bigramBeatPosTransitions[position] = list(lengths)

    for position, lengths in bigramBeatPosTransitions.items():
        total_lengths = sum(beat_pos_counts[position].values())
        for length in lengths:
            bigramBeatPosTransitionProbabilities[position].append(beat_pos_counts[position][length] / total_lengths)

    return bigramBeatPosTransitions, bigramBeatPosTransitionProbabilities

# %%
def beat_bigram_perplexity(midi_file):
    bigramBeatTransitions, bigramBeatTransitionProbabilities = beat_bigram_probability(midi_files)
    bigramBeatPosTransitions, bigramBeatPosTransitionProbabilities = beat_pos_bigram_probability(midi_files)
    # Q8b: Your code goes here
    # Hint: one more probability function needs to be computed
    beat_positions_lengths = beat_extraction(midi_file)
    beat_positions = [position for position, _ in beat_positions_lengths]
    beat_lengths = [length for _, length in beat_positions_lengths]

    N = len(beat_positions_lengths)

    log_probs_Q7 = []
    log_probs_Q8 = []

    unigramLengthProbabilities = {}
    length_counts = Counter(beat_lengths)
    for length in length_counts.keys():
        unigramLengthProbabilities[length] = length_counts[length] / N
    prob = unigramLengthProbabilities[beat_lengths[0]]
    log_probs_Q7.append(np.log(prob))

    for i in range(N - 1):
        prev_length = beat_lengths[i]
        length = beat_lengths[i + 1]
        idx = bigramBeatTransitions[prev_length].index(length)
        prob = bigramBeatTransitionProbabilities[prev_length][idx]
        log_probs_Q7.append(np.log(prob))  # p(length | prev_length)

    for i in range(N):
        length = beat_lengths[i]
        position = beat_positions[i]
        idx = bigramBeatPosTransitions[position].index(length)
        prob = bigramBeatPosTransitionProbabilities[position][idx]
        log_probs_Q8.append(np.log(prob))  # p(length | position)

    # perplexity for Q7
    perplexity_Q7 = np.exp(-np.sum(log_probs_Q7) / len(log_probs_Q7))

    # perplexity for Q8
    perplexity_Q8 = np.exp(-np.sum(log_probs_Q8) / len(log_probs_Q8))

    return perplexity_Q7, perplexity_Q8

# %% [markdown]
# 9. Implement a Markov chain that computes p(beat_length | previous_beat_length, beat_position), and report its perplexity.
#
# `beat_trigram_probability()`
# - **Input**: all midi files `midi_files`
#
# - **Output**: two dictionaries:
#
#   - `trigramBeatTransitions`: key: (previous_beat_length, beat_position), value: a list of beat_length
#
#   - `trigramBeatTransitionProbabilities`: key: (previous_beat_length, beat_position), value: a list of probabilities for beat_length in the same order of `trigramBeatTransitions`
#
# `beat_trigram_perplexity()`
# - **Input**: a midi file
#
# - **Output**: perplexity value

# %%
def beat_trigram_probability(midi_files):
    trigramBeatTransitions = defaultdict(list)
    trigramBeatTransitionProbabilities = defaultdict(list)

    # Q9a: Your code goes here
    for midi_file in midi_files:
        beat_positions_lengths = beat_extraction(midi_file)
        for i in range(len(beat_positions_lengths) - 1):
            prev_length = beat_positions_lengths[i][1]
            curr_position = beat_positions_lengths[i+1][0]
            curr_length = beat_positions_lengths[i+1][1]
            key = (prev_length, curr_position)
            trigramBeatTransitions[key].append(curr_length)

    for key, lengths in trigramBeatTransitions.items():
        length_counts = Counter(lengths)
        total_lengths = sum(length_counts.values())
        transitions = [length for length in length_counts.keys()]
        probs = [length_counts[length] / total_lengths for length in transitions]
        trigramBeatTransitions[key] = transitions
        trigramBeatTransitionProbabilities[key] = probs

    return trigramBeatTransitions, trigramBeatTransitionProbabilities

# %%
def beat_trigram_perplexity(midi_file):
    bigramBeatPosTransitions, bigramBeatPosTransitionProbabilities = beat_pos_bigram_probability(midi_files)
    trigramBeatTransitions, trigramBeatTransitionProbabilities = beat_trigram_probability(midi_files)
    # Q9b: Your code goes here
    beat_positions_lengths = beat_extraction(midi_file)

    N = len(beat_positions_lengths)
    log_probs = []

    position = beat_positions_lengths[0][0]
    length = beat_positions_lengths[0][1]
    index = bigramBeatPosTransitions[position].index(length)
    prob = bigramBeatPosTransitionProbabilities[position][index]
    log_probs.append(np.log(prob))

    for i in range(1, N):
        prev_length = beat_positions_lengths[i - 1][1]
        curr_position = beat_positions_lengths[i][0]
        curr_length = beat_positions_lengths[i][1]
        key = (prev_length, curr_position)
        index = trigramBeatTransitions[key].index(curr_length)
        prob = trigramBeatTransitionProbabilities[key][index]
        log_probs.append(np.log(prob))

    perplexity = np.exp(-np.sum(log_probs) / len(log_probs))
    return perplexity

# %% [markdown]
# 10. Use the model from Q5 to generate N notes, and the model from Q8 to generate beat lengths for each note. Save the generated music as a midi file (see code from workbook1) as q10.mid. Remember to reset the beat position to 0 when reaching the end of a bar.
#
# `music_generate`
# - **Input**: target length, e.g. 500
#
# - **Output**: a midi file q10.mid
#
# Note: the duration of one beat in MIDIUtil is 1, while in MidiTok is 8. Divide beat length by 8 if you use methods in MIDIUtil to save midi files.

# %%
def music_generate(length):
    # sample notes
    unigramProbabilities = note_unigram_probability(midi_files)
    bigramTransitions, bigramTransitionProbabilities = note_bigram_probability(midi_files)
    trigramTransitions, trigramTransitionProbabilities = note_trigram_probability(midi_files)

    # Q10: Your code goes here ...
    sampled_notes = []
    notes = list(unigramProbabilities.keys())
    first_note = random.choices(notes, weights=unigramProbabilities.values())[0]
    sampled_notes.append(first_note)
    sampled_notes.append(sample_next_note(first_note))

    for _ in range(2, length):
        prev_notes = (sampled_notes[-2], sampled_notes[-1])
        if prev_notes in trigramTransitions:
            notes = trigramTransitions[prev_notes]
            probs = trigramTransitionProbabilities[prev_notes]
            sampled_notes.append(random.choices(notes, weights=probs)[0])
        else:
            print("dump 0")
            sampled_notes.append(random.choice(notes))

    # sample beats
    sampled_beats = []
    beat_pos_transitions, beat_pos_probabilities = beat_pos_bigram_probability(midi_files)
    # print(beat_pos_transitions.keys())
    current_position = 0
    for i in range(length):
        if current_position in beat_pos_transitions.keys():
            # print("not dump")
            beats = beat_pos_transitions[current_position]
            probs = beat_pos_probabilities[current_position]
            beat_length = random.choices(beats, weights=probs)[0]
        else:
            print("dump 1", current_position)
            beat_length = random.choice(list(duration2length.values()))
        sampled_beats.append((current_position, beat_length))
        current_position = (current_position + beat_length) % 32

    # save the generated music as a midi file
    midi = MIDIFile(1) # Create a MIDI file that consists of 1 track
    track = 0 # Set track number
    time = 0 # Where is the event placed (at the beginning)
    tempo = 120 # The tempo (beats per minute)
    midi.addTempo(track, time, tempo) # Add tempo information
    channel = 0
    volume = 100
    for i in range(length):
        pitch = sampled_notes[i]
        _, beat_length = sampled_beats[i]
        duration = beat_length / 8  # convert REMI to MIDI beat duration
        midi.addNote(track, channel, pitch, time, duration, volume)
        time += duration
    # add notes to MIDI file
    with open("q10.mid", "wb") as f:
        midi.writeFile(f)

# %%
# comment this out when submitting
music_generate(500)
